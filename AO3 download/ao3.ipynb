# %%
import AO3
import pandas as pd
import requests
from AO3.requester import requester
from bs4 import BeautifulSoup
from tqdm.auto import tqdm, trange
import time
import os
import sys
import csv

# %%
# %%time
    
workid = 13272438

print(f"Work ID: {workid}")
work = AO3.Work(workid, load=True, load_chapters=False)
print(f"Chapters: {work.nchapters}")
# work.metadata
# Out:
# Work ID: 13272438
# Chapters: 3
# Wall time: 1.14 s

# %%
# %%time

work = AO3.Work(13272438)

print(work.chapters[0].title)  # First chapter name
text = work.chapters[0].text  # First chapter text
print(' '.join(text.split(" ")[:30]))
# Out:
# Victory Condition
# “Well, this is awkward,” Megatron said, when they finally gave up trying to push their way out.
# Optimus stared at the ceiling, which was precisely 36.7 centimeters away from his optics,
# Wall time: 1.07 s

# %%
# %%time

search = AO3.Search(any_field="a/b/o", word_count=AO3.utils.Constraint(5000, 15000))
search.update()
print("Total results:", search.total_results)
for result in search.results:
    print(result)
# Out:
# Total results: 5615
# <Work [b o o b a]>
# <Work [A/B/O 2.0]>
# <Work [A.B.O]>
# <Work [T.A.B.O.O]>
# <Work [A/B/O Dynamics]>
# <Work [A/B/O Mine]>
# <Work [A/B/O Havoc]>
# <Work [A/B/O Week]>
# <Work [A/B/O Stiffenverse]>
# <Work [A/B/O Verse]>
# <Work [A/B/O McHanzo Collection]>
# <Work [Merry A/B/O Christmas]>
# <Work [Easy as O, A, B]>
# <Work [RT/AH A/B/O]>
# <Work [Day 31:A/B/O+Threesome]>
# <Work [Wolfstar family (a/b/o)]>
# <Work [woosanhwa a/b/o-ish]>
# <Work [white collar a/b/o braintic 1]>
# <Work [woosan: a/b/o (college) edition]>
# <Work [Short drabbles of A/B/O]>
# Wall time: 1.33 s

# %% [markdown]
# # BAND FIC COUNT

# %%
fandoms = {}
fandom_key = 'Music%20*a*%20Bands'
url = f"https://archiveofourown.org/media/{fandom_key}/fandoms"
print(f"Downloading from {url}")
# req = requester.request("get", url)
req = requests.get(url)
soup = BeautifulSoup(req.content, "lxml")
i = 0
for fandom in soup.find("ol", {"class": "alphabet fandom index group"}).findAll("li", {"class": None}):
    string = fandom.getText()
    print(string)
    fandom = string.split('\n')[1]
    n_works = string.split('\n')[2][:-1].split('(')[1] 
    fandoms[fandom] = int(n_works)
# Out:
# Downloading from https://archiveofourown.org/media/Music%20*a*%20Bands/fandoms
#
# &AUDITION Boys (Band)
#                 (5)
#
#
# $uicideboy$ (Band)
#                 (4)
#
#
# the 1 - Taylor Swift (Song)
#                 (3)
#
#
# 1 Trait Danger (Band)
#                 (3)
#
#
# 100 Gecs (Band)
#                 (8)
#
#
# 100 Monkeys
#                 (2)
#
#
# 백퍼센트 | 100 Percent (Band)
#                 (13)
#
#
# 娛樂百分百 | 100 Percent Entertainment (TV)
#                 (511)
#
#
# 100 Years - Five for Fighting (Song)
#                 (2)
#
#
# 12 Stones (Band)
#                 (1)
#
#
# 12012 (Band)
#                 (7)
#
#
# The 13th Floor Elevators (Band)
#                 (1)
#
#
# 14U (Band)
#                 (5)
#
#
# 15& (Band)
#                 (69)
#
#
# 176BIZ (Japan Band)
#                 (2)
#
#
# 1950 - King Princess (Song)
#                 (1)
#
#
# 1952 Vincent Black Lightning (Song)
#                 (2)
#
#
# 1960s Music Scene RPF
#                 (6078)
#
#
# The 1975 (Band)
#                 (332)
#
#
# 1989 - Taylor Swift (Album)
#                 (5)
#
#
# 1NB (Band)
#                 (1)
#
#
# 1PUNCH (Band)
#                 (23)
#
#
# 1TEAM (Band)
#                 (32)
#
#
# 1The9 (Band)
#                 (47)
#
#
# 1TYM
#                 (5)
#
#
# 1년 정거장 | One Year Station - G-Dragon (Song)
#                 (1)
#
#
# 21st Century Breakdown - Green Day (Album)
#                 (11)
#
#
# 24 Italian Art Songs and Arias
#                 (2)
#
#
# 24K (Band)
#                 (36)
#
#
# 250000 Miles - Patty Griffin (Song)
#                 (1)
#
#
# 2AM (Band)
#                 (19)
#
#
# 2Cellos
#                 (26)
#
#
# 2gether (US Band)
#                 (7)
#
#
# #2Маши | #2Mashi (Band)
#                 (21)
#
#
# 2NE1
#                 (219)
#
#
# 2PM (Band)
#                 (353)
#
#
# 2wo (Band)
#                 (2)
#
#
# 2Z (Korea Band)
#                 (2)
#
#
# 30 Days - Never Shout Never (Song)
#                 (1)
#
#
# 30 Seconds to Mars
#                 (746)
#
#
# 365 Fresh - Triple H (Music Video)
#                 (9)
#
#
# '39 - Queen (Song)
#                 (2)
#
#
# 3OH!3
#                 (4)
#
#
# 3YE (Korea Band)
#                 (3)
#
#
# 네시 | 4 O'Clock - RM & V (Song)
#                 (3)
#
#
# 4'33" - John Cage (Song)
#                 (21)
#
#
# +44 (Band)
#                 (12)
#
#
# 4minute (Band)
#                 (75)
#
#
# 4Ten (Band)
#                 (1)
#
#
# 4tune_UNIT
#                 (2)
#
#
# 5 Seconds of Summer (Band)
#                 (10043)
#
#
# 504 Plan
#                 (1)
#
#
# The 51st Highland Division's Farewell to Sicily - Hamish Henderson (Song)
#                 (1)
#
#
# 5urprise (Band)
#                 (9)
#
#
# 6/10 - Dodie Clark (Song)
#                 (3)
#
#
# 69 Eyes
#                 (15)
#
#
# 6969 - Ninja Sex Party (Song)
#                 (22)
#
#
# 7 MEN 侍 | 7 MEN Samurai (Band)
#                 (40)
#
#
# 74 - Itoki Hana & Toby Fox (Song)
#                 (1)
#
#
# 747 (Strangers In The Night) - Saxon (Song)
#                 (1)
#
#
# 777 | Triple 7 (Korea Band)
#                 (1)
#
#
# 7WEST
#                 (1)
#
#
# 8.32 - Luna (Song)
#                 (1)
#
#
# 867-5309/Jenny - Tommy Tutone (Song)
#                 (2)
#
#
# 88 Lines About 44 Women - The Nails (Song)
#                 (1)
#
#
# 8P-SB (Band)
#                 (5)
#
#
# 9 to 5 - Dolly Parton (Song)
#                 (3)
#
#
# 98 Degrees
#                 (3)
#
#
# 99 Luftballons | 99 Red Balloons - Nena (Song)
#                 (8)
#
#
# 999 (Band)
#                 (2)
#
#
# 9GOATS BLACK OUT
#                 (14)
#
#
# 9x9 | NINE BY NINE (BAND)
#                 (3)
#
#
# A Pink (Band)
#                 (118)
#
#
# А что нам надо? - СерьГа | A shto nam nado? - SerGa (Song)
#                 (1)
#
#
# a-ha (Band)
#                 (3)
#
#
# A-Jax (Band)
#                 (2)
#
#
# A-Teens (Sweden Band)
#                 (1)
#
#
# A.B.C.-Z
#                 (57)
#
#
# A.C.E (Beat Interactive Band)
#                 (1280)
#
#
# A.cian (Band)
#                 (2)
#
#
# A.DE (Band)
#                 (1)
#
#
# A.I.VOICE
#                 (1)
#
#
# A.KOR
#                 (3)
#
#
# A$AP Mob
#                 (1)
#
#
# A1
#                 (2)
#
#
# A6P (Band)
#                 (2)
#
#
# A9 | Alice Nine (Band)
#                 (471)
#
#
# AAA (Band)
#                 (35)
#
#
# Aaliyah (Musician) RPF
#                 (3)
#
#
# AB6IX (Band)
#                 (634)
#
#
# ABBA (Band)
#                 (33)
#
#
# Abbey Death (Band)
#                 (1)
#
#
# ABC (UK Band)
#                 (3)
#
#
# Abingdon Boys School (Band)
#                 (7)
#
#
# Abney Park
#                 (4)
#
#
# Abraham's Daughter - Arcade Fire (Song)
#                 (6)
#
#
# Abù - Bandabardò (Song)
#                 (1)
#
#
# AC/DC (Band)
#                 (23)
#
#
# The Academy Is...
#                 (985)
#
#
# Ace of Base
#                 (1)
#
#
# Ace of Spades (Japan Band)
#                 (1)
#
#
# Acele - Carla's Dreams (Song)
#                 (1)
#
#
# Acid Android (Band)
#                 (3)
#
#
# Acid Black Cherry
#                 (10)
#
#
# Act Series - The Dear Hunter (Albums)
#                 (4)
#
#
# Adam - Alex G (Song)
#                 (1)
#
#
# Dat Adam (Band)
#                 (1)
#
#
# Adam Ant (Musician)
#                 (5)
#
#
# Adam Lambert (Musician)
#                 (4264)
#
#
# Adam Levine (Musician)
#                 (171)
#
#
# Adam Young (Musician) RPF
#                 (19)
#
#
# ADAMS (Band)
#                 (7)
#
#
# Addict With a Pen - Twenty One Pilots (Song)
#                 (2)
#
#
# Addicted - PIXY (Music Video)
#                 (2)
#
#
# Addicted to You - Avicii (Music Video)
#                 (8)
#
#
# Addiction (Japan Band)
#                 (1)
#
#
# Adele (Musician)
#                 (5)
#
#
# Adema (Band)
#                 (1)
#
#
# Adonai - Lord of the Lost (Song)
#                 (1)
#
#
# Adore You - Harry Styles (Song)
#                 (48)
#
#
# Adrenaline Mob (Band)
#                 (1)
#
#
# A ぇ! Group! | Ae! Group! (Band)
#                 (3)
#
#
# Aelonia (Band)
#                 (2)
#
#
# Aerosmith (Band)
#                 (22)
#
#
# Aespa (Band)
#                 (407)
#
#
# Aeterno - Aviators (Album)
#                 (2)
#
#
# AFI (Band)
#                 (323)
#
#
# Africa - Rose Laurens (Song)
#                 (1)
#
#
# Africa - Toto (Song)
#                 (2)
#
#
# After School (Band)
#                 (58)
#
#
# After School Club (TV)
#                 (9)
#
#
# After the Gold Rush - Neil Young (Song)
#                 (2)
#
#
# After the Rain Has Fallen - Sting (Song)
#                 (1)
#
#
# Afterhours (Band)
#                 (147)
#
#
# Against Me!
#                 (9)
#
#
# Against the Current (Band)
#                 (4)
#
#
# Агата Кристи | Agatha Christie (Band)
#                 (61)
#
#
# 特務J - 蔡依林 | Agent J - Jolin Tsai (Song)
#                 (1)
#
#
# Agnete og Havmanden (Song)
#                 (2)
#
#
# The Agonist
#                 (1)
#
#
# Ангел С Грязным Лицом - Кукрыниксы | Ahngel C Gryznym Litsom - Kukryniksy (Song)
#                 (1)
#
#
# 愛狂います。| Aicle.
#                 (2)
#
#
# АИГЕЛ | AIGEL (Band)
#                 (1)
#
#
# AILE (Band)
#                 (1)
#
#
# Ailee (Musician)
#                 (20)
#
#
# Ailein Duinn - Karliene (Song)
#                 (1)
#
#
# Aims - Vienna Teng (Album)
#                 (2)
#
#
# Ain't No Sunshine - Bill Withers (Song)
#                 (1)
#
#
# Aiolin (Band)
#                 (1)
#
#
# Airplane (Korea Band)
#                 (1)
#
#
# Airwaves (Song)
#                 (1)
#
#
# AIsingers
#                 (1)
#
#
# AJJ (Band)
#                 (1)
#
#
# AJR (Band)
#                 (22)
#
#
# Ak Dong Club
#                 (1)
#
#
# AKB48
#                 (257)
#
#
# AKB48 & Related Fandoms
#                 (697)
#
#
# Akdong Musician
#                 (23)
#
#
# Alabama 3
#                 (2)
#
#
# Alabama Motel Room - Matthew Good Band (Song)
#                 (1)
#
#
# Aladdin Sane - David Bowie (Album)
#                 (1)
#
#
# Alamat (Band)
#                 (13)
#
#
# Alanis Morissette (Musician)
#                 (3)
#
#
# Alcest (Band)
#                 (1)
#
#
# Aldious (Band)
#                 (1)
#
#
# Alejandro - Lady Gaga (Music Video)
#                 (2)
#
#
# Alesana (Band)
#                 (1)
#
#
# Alestorm (Band)
#                 (3)
#
#
# Alexandros (Japan Band)
#                 (1)
#
#
# Ансамбль Александрова | Alexandrov Ensemble | Red Army Choir
#                 (30)
#
#
# Ali Project (Band)
#                 (1)
#
#
# Alibi - Dessa (Song)
#                 (1)
#
#
# Alice - The Mechanisms (Song)
#                 (2)
#
#
# Alice - Tom Waits (Album)
#                 (1)
#
#
# Alice Cooper (Band)
#                 (1)
#
#
# Alice Cooper (Musician) RPF
#                 (39)
#
#
# Alice in Chains
#                 (111)
#
#
# Alice's Restaurant - Arlo Guthrie (Song)
#                 (1)
#
#
# Alicia Keys (Musician)
#                 (3)
#
#
# Aliene Ma'riage (Band)
#                 (1)
#
#
# Alkaline Trio (Band)
#                 (68)
#
#
# All Along the Watchtower (Song)
#                 (1)
#
#
# ALL CITY STEPPERS (Band)
#                 (2)
#
#
# All Eyes On Me - Bo Burnham (Song)
#                 (5)
#
#
# 以团之名 | All for One (TV)
#                 (20)
#
#
# All I Want - Emma Bale (Song)
#                 (1)
#
#
# 걸어 | All in - Monsta X (Music Video)
#                 (56)
#
#
# All Souls Night - Loreena McKennitt (Song)
#                 (2)
#
#
# All This Bad Blood - Bastille (Album)
#                 (4)
#
#
# All Time Low (Band)
#                 (1758)
#
#
# All Too Well - Taylor Swift (Song)
#                 (1)
#
#
# All-American Rejects
#                 (83)
#
#
# Alleluia - Dar Williams (Song)
#                 (3)
#
#
# Allen Mack Myers Moore (Band)
#                 (3)
#
#
# Allison Iraheta (Musician)
#                 (8)
#
#
# ALLS-GIRL (Korea Band)
#                 (1)
#
#
# The Almost
#                 (1)
#
#
# Alone - Alan Walker (Music Video)
#                 (1)
#
#
# ALPHA (Korea Band)
#                 (1)
#
#
# 알파벳 | AlphaBAT
#                 (5)
#
#
# alt-J (Band)
#                 (1)
#
#
# Alter Bridge
#                 (4)
#
#
# Alternative Girlfriend - The Barenaked Ladies (Song)
#                 (1)
#
#
# The Altogether (Band)
#                 (4)
#
#
# ALvino (Band)
#                 (2)
#
#
# Am Donaustrande - Brahms (Song)
#                 (1)
#
#
# Am I the Only One? - Dierks B Bentley (Song)
#                 (1)
#
#
# Amanda Lopiccolo (Musician)
#                 (1)
#
#
# Amanda Palmer (Musician)
#                 (20)
#
#
# Les amants d'un jour - Edith Piaf (Song)
#                 (1)
#
#
# Amaranthe (Band)
#                 (4)
#
#
# The Amazing Devil (Band)
#                 (15)
#
#
# Ambeon (Band)
#                 (1)
#
#
# America - Simon & Garfunkel (Song)
#                 (1)
#
#
# America Fuck Yeah! - Team America (Song)
#                 (1)
#
#
# America's Suitehearts - Fall Out Boy (Music Video)
#                 (66)
#
#
# American Idiot - Green Day (Album)
#                 (54)
#
#
# American Murder Song - Various (Album)
#                 (18)
#
#
# American Oxygen - Rihanna (Music Video)
#                 (1)
#
#
# American Pie - Don McLean (Song)
#                 (2)
#
#
# American Soldier - Toby Keith (Song)
#                 (1)
#
#
# Americano - Lady Gaga (Song)
#                 (1)
#
#
# Amici di Maria de Filippi (TV) RPF
#                 (3)
#
#
# The Amity Affliction
#                 (5)
#
#
# Amnesia Was Her Name - Lemon Demon (Song)
#                 (2)
#
#
# Amon Amarth (Band)
#                 (3)
#
#
# Amurekimuri (Band)
#                 (1)
#
#
# An Hini A Garan - Denez Prigent (Song)
#                 (1)
#
#
# Ana Ng - They Might Be Giants (Song)
#                 (1)
#
#
# Anaal Nathrakh (Band)
#                 (1)
#
#
# Anatomy of a Murder - Duke Ellington (Album)
#                 (1)
#
#
# Anavitória (Band)
#                 (1)
#
#
# Anberlin
#                 (1)
#
#
# And the Band Played Waltzing Matilda - Eric Bogle (Song)
#                 (1)
#
#
# And You Give - Matthew Barber (Music Video)
#                 (1)
#
#
# Andrew Bird & the Mysterious Production of Eggs - Andrew Bird (Album)
#                 (4)
#
#
# Andrew Hozier-Byrne (Musician)
#                 (184)
#
#
# Andrew in Drag - The Magnetic Fields (Song)
#                 (3)
#
#
# Andrew W. K. (Musician)
#                 (1)
#
#
# Andy You're A Star - The Killers (Song)
#                 (3)
#
#
# Angdreville | ADV
#                 (5)
#
#
# Angel Of Small Death & The Codeine Scene - Hozier (Song)
#                 (1)
#
#
# Angelo (Band)
#                 (29)
#
#
# Angels & Airwaves
#                 (26)
#
#
# Angie Baby - Helen Reddy (Song)
#                 (2)
#
#
# Angra (Band)
#                 (6)
#
#
# Angus & Julia Stone
#                 (1)
#
#
# The Animals (Band)
#                 (1)
#
#
# Anli Pollicino
#                 (8)
#
#
# Anna Blue (Musician)
#                 (1)
#
#
# Annan Water (Traditional Ballad)
#                 (2)
#
#
# Die Another Day - Madonna (Music Video)
#                 (1)
#
#
# ANS (Korea Band)
#                 (2)
#
#
# Antenna Angels (Band)
#                 (2)
#
#
# Anteros (Band)
#                 (5)
#
#
# Anthem Lights (Band)
#                 (1)
#
#
# Anthrax (US Band)
#                 (77)
#
#
# Antic Cafe (Band)
#                 (12)
#
#
# Antichrist Superstar - Marilyn Manson (Album)
#                 (12)
#
#
# Die Antwoord (Band)
#                 (3)
#
#
# AnyBand
#                 (5)
#
#
# AOA | Ace of Angels
#                 (83)
#
#
# ApeCrime (Band)
#                 (1)
#
#
# Apex - Ky Rodgers (Song)
#                 (1)
#
#
# Aphex Twin
#                 (3)
#
#
# Aphrodisiac - IAMX (Song)
#                 (1)
#
#
# Apocalyptica (Band)
#                 (93)
#
#
# Appelle mon numéro - Mylène Farmer (Music Video)
#                 (1)
#
#
# Appetite of a People-Pleaser - GHOST | GHOST and Pals ft. v4 flower (Song)
#                 (1)
#
#
# Apple Candy - Ben Lee (Song)
#                 (1)
#
#
# Apple.B (Band)
#                 (1)
#
#
# L'apprenti sorcier | The Sorcerer's Apprentice - Paul Dukas (Song)
#                 (1)
#
#
# April (Band)
#                 (10)
#
#
# April Come She Will - Simon & Garfunkel (Song)
#                 (3)
#
#
# Aquarium - Camille Saint-Saens (Song)
#                 (1)
#
#
# Aquarium (Russia Band)
#                 (7)
#
#
# Arashi (Band)
#                 (6946)
#
#
# Arcade Fire (Band)
#                 (3)
#
#
# Arcadia (UK Band)
#                 (51)
#
#
# Arch Enemy (Band)
#                 (1)
#
#
# Archaeopteryx - Lemon Demon (Song)
#                 (1)
#
#
# The ArchAndroid - Janelle Monáe
#                 (14)
#
#
# Architects (UK Band)
#                 (7)
#
#
# Arctic Monkeys
#                 (717)
#
#
# Area 11
#                 (15)
#
#
# Arege (Band)
#                 (1)
#
#
# The Arena - Lindsey Stirling (Music Video)
#                 (2)
#
#
# Argon (Korea Band)
#                 (1)
#
#
# Ari Hest (Musician)
#                 (1)
#
#
# Ария | Aria (Russia Band)
#                 (26)
#
#
# Ariana Grande (Musician)
#                 (72)
#
#
# Aristocrat - Poppy (Song)
#                 (1)
#
#
# The Ark (Korea Band)
#                 (7)
#
#
# Arlequin (Japan Band)
#                 (4)
#
#
# Arma Angelus
#                 (5)
#
#
# The Arrogant Worms
#                 (1)
#
#
# Артерия | Arteria (Band)
#                 (1)
#
#
# Артур Беркут | Arthur Berkut (Musician)
#                 (1)
#
#
# Arven (Band)
#                 (1)
#
#
# Die Ärzte
#                 (50)
#
#
# As December Falls (Band)
#                 (1)
#
#
# As It Is (Band)
#                 (83)
#
#
# As it Was - Hozier (Song)
#                 (1)
#
#
# As the World Caves In - Matt Maltese (Song)
#                 (3)
#
#
# As the World Falls Down - David Bowie (Music Video)
#                 (2)
#
#
# Aserejé | The Ketchup Song - Las Ketchup (Song)
#                 (1)
#
#
# Ashestoangels (Band)
#                 (1)
#
#
# Ashlee Simpson (Musician)
#                 (15)
#
#
# Ashley Dzerigian (Musician)
#                 (21)
#
#
# Asia (UK Band)
#                 (1)
#
#
# ASIAN KUNG-FU GENERATION (Band)
#                 (1)
#
#
# Aska - unterART (Song)
#                 (1)
#
#
# Asking Alexandria (Band)
#                 (55)
#
#
# L'Assasymphonie - Florent Mothe (Song)
#                 (4)
#
#
# Assimilate (2019)
#                 (1)
#
#
# ASTRO (Band)
#                 (2215)
#
#
# Astronaut - Amanda Palmer (Song)
#                 (4)
#
#
# At the Gates (Band)
#                 (1)
#
#
# 新しい学校のリーダーズ | Atarashii Gakkou no Leaders (Band)
#                 (1)
#
#
# ATEEZ (Band)
#                 (11089)
#
#
# Athena - CircusP & CrusherP (Song)
#                 (1)
#
#
# Atlantic City - Bruce Springsteen (Song)
#                 (5)
#
#
# Atomic Copper Claw - Lemon Demon (Song)
#                 (1)
#
#
# Atomic Kitten (Band)
#                 (1)
#
#
# Atreyu (Band)
#                 (4)
#
#
# Attack Attack! (Band)
#                 (14)
#
#
# Attila (Band 2005)
#                 (2)
#
#
# Audioslave (Band)
#                 (20)
#
#
# august - Taylor Swift (Song)
#                 (21)
#
#
# Augustana (Band)
#                 (1)
#
#
# АукцЫон | Auktyon (Band)
#                 (1)
#
#
# Aural Vampire
#                 (1)
#
#
# AURORA (Norway Musician)
#                 (4)
#
#
# Austin - Blake Shelton (Song)
#                 (2)
#
#
# Austin & Ally RPF
#                 (19)
#
#
# Austin Mahone (Musician)
#                 (11)
#
#
# Australian Idol RPF
#                 (2)
#
#
# Autumn's Here - Hawksley Workman (Song)
#                 (1)
#
#
# Avalon - Roxy Music (Album)
#                 (1)
#
#
# Avantasia (Band)
#                 (35)
#
#
# Avatar (Sweden Band)
#                 (43)
#
#
# AvelCain (Band)
#                 (1)
#
#
# Avenged Sevenfold
#                 (397)
#
#
# Avril Lavigne (Musician)
#                 (17)
#
#
# AWS (Band)
#                 (1)
#
#
# Axel F - Crazy Frog (Music Video)
#                 (3)
#
#
# Axl Rose (Musician)
#                 (31)
#
#
# Aya (Musician)
#                 (1)
#
#
# Ayabie (Band)
#                 (47)
#
#
# Ayreon (Band)
#                 (3)
#
#
# Ayria (Band)
#                 (1)
#
#
# Ayumi Hamasaki (Musician)
#                 (1)
#
#
# AZALEA (Japan Band)
#                 (1)
#
#
# Aztec Camera (Band)
#                 (1)
#
#
# The B-52s (Band)
#                 (1)
#
#
# B.A.P
#                 (2232)
#
#
# B.I.G | Boys in Groove
#                 (45)
#
#
# B.I.Shadow
#                 (15)
#
#
# B.O.Y (Korea Band)
#                 (16)
#
#
# B1A4
#                 (165)
#
#
# B5 (US Band)
#                 (1)
#
#
# Babe - Sugarland ft. Taylor Swift (Music Video)
#                 (2)
#
#
# Babes in Toyland (Band)
#                 (1)
#
#
# Babooshka - Kate Bush (Song)
#                 (1)
#
#
# Baby It's Cold Outside - Frank Loesser (Song)
#                 (3)
#
#
# Baby Shark - Pingfong (Song)
#                 (1)
#
#
# Baby You're a Rich Man - Beatles (Song)
#                 (1)
#
#
# BabyKingdom (Band)
#                 (1)
#
#
# BABYMETAL
#                 (25)
#
#
# Babyshambles (Band)
#                 (3)
#
#
# Des Baches Wiegenlied - Franz Schubert (Song)
#                 (2)
#
#
# The Back Seat of My Car - Linda McCartney and Paul McCartney (Song)
#                 (1)
#
#
# Back to December - Taylor Swift (Song)
#                 (1)
#
#
# The Background Noise - IAMX (Song)
#                 (1)
#
#
# Backstreet Boys
#                 (1442)
#
#
# Backstreets - Bruce Springsteen (Song)
#                 (2)
#
#
# Bad - Michael Jackson (Music Video)
#                 (10)
#
#
# Bad at Love - Halsey (Music Video)
#                 (1)
#
#
# Bad Bad Leroy Brown - Jim Croce (Song)
#                 (1)
#
#
# Bad Blood - Taylor Swift (Music Video)
#                 (65)
#
#
# Bad Girl - Madonna (Music Video)
#                 (6)
#
#
# Bad Idea - Moon Bin & Sanha (Music Video)
#                 (1)
#
#
# Bad Love - Key (Music Video)
#                 (1)
#
#
# Bad Romance - Lady Gaga (Music Video)
#                 (2)
#
#
# Bad Suns (Band)
#                 (3)
#
#
# Badflower (Band)
#                 (11)
#
#
# Badlands - Halsey (Album)
#                 (21)
#
#
# BAE173 (Band)
#                 (47)
#
#
# Bagger 288 - Rathergood (Song)
#                 (1)
#
#
# Bagman's Gambit - The Decemberists
#                 (1)
#
#
# BAISER (Band)
#                 (1)
#
#
# Ball Cap - Mother Mother (Song)
#                 (2)
#
#
# The Ballad of Lucy Jordan - Marianne Faithfull (Song)
#                 (1)
#
#
# Ballad of Mona Lisa - Panic! At the Disco (Music Video)
#                 (3)
#
#
# The Ballad of Mona Lisa - Panic! at the Disco (Song)
#                 (2)
#
#
# The Ballad of Tim Horton's - The Arrogant Worms (Song)
#                 (1)
#
#
# Ballistik Boyz from Exile Tribe (Band)
#                 (7)
#
#
# Ballroom Blitz - Sweet (Song)
#                 (1)
#
#
# Banana Man - Tally Hall (Song)
#                 (1)
#
#
# Bananarama (Band)
#                 (1)
#
#
# The Band (Band 1968)
#                 (24)
#
#
# The Band (Canada Band)
#                 (1)
#
#
# BAND-MAID (Band)
#                 (5)
#
#
# Bandom
#                 (56377)
#
#
# Bang Bang! (2014)
#                 (1)
#
#
# Bangarang - Skrillex (Music Video)
#                 (2)
#
#
# The Bangles (Band)
#                 (1)
#
#
# 방탄소년단 | Bangtan Boys | BTS
#                 (169903)
#
#
# The Bard's Song (In the Forest) - Blind Guardian (Song)
#                 (1)
#
#
# Barenaked Ladies (Band)
#                 (5)
#
#
# Barrett's Privateers (Song)
#                 (7)
#
#
# Barriers - Frank Iero and the Future Violents (Album)
#                 (2)
#
#
# Barry Manilow (Musician)
#                 (3)
#
#
# Bars and Melody (Band)
#                 (2)
#
#
# Barton Hollow - The Civil Wars (Song)
#                 (1)
#
#
# The Baseballs (Band)
#                 (8)
#
#
# Bastille (Band)
#                 (498)
#
#
# Bat Out of Hell Trilogy - Meat Loaf (Albums)
#                 (2)
#
#
# BatAAR (Band)
#                 (2)
#
#
# Bathory (Band)
#                 (1)
#
#
# Battle (Korea Band)
#                 (2)
#
#
# Bauhaus
#                 (10)
#
#
# Baumkuchen End - E ve (Music Video)
#                 (6)
#
#
# Bay City Rollers (Band)
#                 (1)
#
#
# BDC | Boys Da Capo (Band)
#                 (20)
#
#
# Be Alright - Dean Lewis (Song)
#                 (1)
#
#
# Be.A (Band)
#                 (1)
#
#
# The Beach Boys (Band)
#                 (17)
#
#
# Beady Eye (Band)
#                 (7)
#
#
# Bears in Trees (Band)
#                 (3)
#
#
# Beartooth (Band)
#                 (2)
#
#
# The Beast Inside - My Enemies and I (Album)
#                 (1)
#
#
# Beastie Boys (Band)
#                 (12)
#
#
# Beat For Beat (TV) RPF
#                 (1)
#
#
# Beat the Champ - The Mountain Goats (Album)
#                 (5)
#
#
# BeatBurger (Band)
#                 (2)
#
#
# Beatcats (Band)
#                 (1)
#
#
# The Beatles (Band)
#                 (5118)
#
#
# Beautiful - Monsta X (Music Video)
#                 (17)
#
#
# Beautiful Ghosts - Taylor Swift (Song)
#                 (1)
#
#
# Beautiful Liar - Shakira & Beyoncé (Song)
#                 (1)
#
#
# Beautiful Liar - VIXX LR (Music Video)
#                 (21)
#
#
# Beautiful Pain - BTOB (Song)
#                 (1)
#
#
# Beautiful Trauma - P!nk (Music Video)
#                 (1)
#
#
# Bebe Rexha (Musician)
#                 (12)
#
#
# BEcause - Dreamcatcher (Music Video)
#                 (1)
#
#
# Because the Internet - Childish Gambino (Album)
#                 (1)
#
#
# Beck (Musician)
#                 (4)
#
#
# Becky G (Musician) RPF
#                 (5)
#
#
# BECZ (Band)
#                 (1)
#
#
# Bed of Roses - Bon Jovi (Song)
#                 (1)
#
#
# Bedstead Men - Flanders and Swann (Song)
#                 (1)
#
#
# Bee Gees (Band)
#                 (5)
#
#
# The Beekeeper - Tori Amos (Album)
#                 (1)
#
#
# Beenzino (Musician)
#                 (1)
#
#
# Before You Exit (Band)
#                 (2)
#
#
# Begin Again - Taylor Swift (Music Video)
#                 (3)
#
#
# Begin Again - Taylor Swift (Song)
#                 (2)
#
#
# Behemoth (Band)
#                 (13)
#
#
# Behind Blue Eyes - The Who (Song)
#                 (3)
#
#
# Behind The Scenes - Francesca Battistelli (Song)
#                 (1)
#
#
# Beirut (Band)
#                 (2)
#
#
# BEJ48 (Band)
#                 (75)
#
#
# Bele Doette (Song)
#                 (2)
#
#
# Believer - Imagine Dragons (Song)
#                 (1)
#
#
# Belle and Sebastian
#                 (1)
#
#
# Bellyache - Billie Eilish (Song)
#                 (4)
#
#
# Belum Tidur - Hindia ft. Sal Priadi (Music Video)
#                 (1)
#
#
# Ben Folds (Musician)
#                 (1)
#
#
# Ben Howard (Musician) RPF
#                 (1)
#
#
# Ben&Ben (Band)
#                 (1)
#
#
# The Bends - Doomtree (Song)
#                 (1)
#
#
# Beovizija RPF
#                 (6)
#
#
# Beretta - Carla's Dreams (Song)
#                 (1)
#
#
# Berry Bell (Band)
#                 (1)
#
#
# Berry Good (Band)
#                 (6)
#
#
# Berryz Koubou
#                 (9)
#
#
# The Best Ever Death Metal Band in Denton - The Mountain Goats (Song)
#                 (4)
#
#
# Best of the Black President - Fela Kuti (Album)
#                 (2)
#
#
# The Best Song Ever - Gabrielle Aplin
#                 (3)
#
#
# Best Song Ever - One Direction (Music Video)
#                 (146)
#
#
# BESTie (Band)
#                 (4)
#
#
# Better Oblivion Community Center (Band)
#                 (1)
#
#
# Better Than I Know Myself - Adam Lambert (Music Video)
#                 (8)
#
#
# Betty - Brooke Fraser (Music Video)
#                 (1)
#
#
# betty - Taylor Swift (Song)
#                 (26)
#
#
# Between Raising Hell and Amazing Grace - Big & Rich (Music Video)
#                 (1)
#
#
# Beulah - John Paul White (Album)
#                 (1)
#
#
# Beyoncé Knowles (Musician)
#                 (35)
#
#
# Beyond (Band)
#                 (13)
#
#
# Beyond Metropolis - Shriekback (Song)
#                 (2)
#
#
# Beyond My Control - Mylène Farmer (Music Video)
#                 (1)
#
#
# Beyond the Veil - Lindsey Stirling (Music Video)
#                 (1)
#
#
# BEYOOOOONDS (Band)
#                 (48)
#
#
# БИ-2 | BI-2 (Band)
#                 (52)
#
#
# Библиотека Просперо | Biblioteka Prospero (Band)
#                 (1)
#
#
# La bicyclette - Yves Montand (Album)
#                 (1)
#
#
# Le bien qui fait mal - Mozart Opera Rock (Song)
#                 (1)
#
#
# The Bifrost Incident - The Mechanisms (Album)
#                 (181)
#
#
# Big Bad Bosses (Band)
#                 (1)
#
#
# Big Bang (Band)
#                 (2534)
#
#
# Big Byung (Band)
#                 (6)
#
#
# Big Enough - Kirin J Callinan ft. Alex Cameron & Molly Lewis & Jimmy Barnes (Music Video)
#                 (2)
#
#
# Big Iron - Marty Robbins (Song)
#                 (4)
#
#
# Big Russian Boss (Musician)
#                 (8)
#
#
# Big Science - Laurie Anderson (Song)
#                 (1)
#
#
# Big Sean (Musician) RPF
#                 (1)
#
#
# Big Time Rush (Band)
#                 (284)
#
#
# 大波浪 | THE BIG WAVE (Band)
#                 (79)
#
#
# BIGFLO
#                 (23)
#
#
# Bigflo & Oli (Band)
#                 (1)
#
#
# The Bigfoot Scenic Byway - Lenny Green (Song)
#                 (1)
#
#
# Bigfoot Stole My Baby - John Lilly (Song)
#                 (1)
#
#
# BIGSTAR (Band)
#                 (18)
#
#
# Bikini Kill (Band)
#                 (3)
#
#
# Billie Eilish (Musician)
#                 (45)
#
#
# Billy Idol (Musician)
#                 (5)
#
#
# Billy Talent (Band)
#                 (6)
#
#
# Birdhouse in Your Soul - They Might Be Giants (Music Video)
#                 (1)
#
#
# Birdhouse in Your Soul - They Might Be Giants (Song)
#                 (5)
#
#
# Birdy (Musician)
#                 (3)
#
#
# Birthday - All Time Low (Song)
#                 (1)
#
#
# The Birthday Massacre (Band)
#                 (1)
#
#
# The Birthday Party (Band)
#                 (10)
#
#
# 美流沙女 | Birushana (1995 Soleil Band)
#                 (1)
#
#
# BiS | Brand-new idol Society (Band)
#                 (1)
#
#
# BiSH | Brand-new idol SHiT (Band)
#                 (1)
#
#
# 美少年 | Bishounen (Band)
#                 (4)
#
#
# Bitch Better Have My Money - Rihanna (Music Video)
#                 (2)
#
#
# The Bix Beiderbecke Legend - Bix Beiderbecke (Album)
#                 (1)
#
#
# Bizarre Love Triangle - New Order (Song)
#                 (1)
#
#
# Bizzy Montana (Musician)
#                 (1)
#
#
# Björk (Musician)
#                 (2)
#
#
# Black 'N Blue (US Band)
#                 (4)
#
#
# Black Cards (Band)
#                 (40)
#
#
# Black Coffee - The Careless Lovers (Music Video)
#                 (1)
#
#
# The Black Crowes (Band)
#                 (1)
#
#
# Black Eyed Peas (Band)
#                 (2)
#
#
# Black Eyes - David Wirsig (Song)
#                 (1)
#
#
# Black Flag (Band)
#                 (4)
#
#
# Black Gene for the Next Scene (Band)
#                 (6)
#
#
# The Black Keys (Band)
#                 (2)
#
#
# Black Klaxon | Astaria (Band)
#                 (1)
#
#
# Black Oxide - Lord of the Lost ft. Scarlet Dorn (Song)
#                 (1)
#
#
# Black Parade - My Chemical Romance (Album)
#                 (58)
#
#
# Black Rebel Motorcycle Club
#                 (5)
#
#
# Black Ring Dreams (Band)
#                 (1)
#
#
# Black Sabbath
#                 (10)
#
#
# The Black Satans
#                 (1)
#
#
# Black Sheep - Gin Wigmore (Song)
#                 (1)
#
#
# THE BLACK SWAN (Band)
#                 (1)
#
#
# Black Swan (Korea Band)
#                 (2)
#
#
# Black Veil Brides
#                 (625)
#
#
# Black-Dove (January) - Tori Amos (Song)
#                 (1)
#
#
# BLACK6IX (Band)
#                 (2)
#
#
# BlackACE (China Band)
#                 (22)
#
#
# Blackfield (Band)
#                 (1)
#
#
# The Blackout (Band)
#                 (3)
#
#
# BLACKPINK (Band)
#                 (2712)
#
#
# Blah Blah (Korea Band)
#                 (1)
#
#
# Blake Shelton (Musician)
#                 (305)
#
#
# BLANC7 (Band)
#                 (8)
#
#
# Blank Space - Taylor Swift (Music Video)
#                 (11)
#
#
# Blank Space - Taylor Swift (Song)
#                 (1)
#
#
# Blaqk Audio
#                 (4)
#
#
# Bleachers (Band)
#                 (4)
#
#
# Bleed in Me - Obscure Sphinx (Song Cycle)
#                 (1)
#
#
# Bleeding Me - Metallica (Song)
#                 (1)
#
#
# Blessthefall (Band)
#                 (7)
#
#
# Blind Channel (Band)
#                 (514)
#
#
# Blind Guardian (Band)
#                 (3)
#
#
# Blind Melon
#                 (30)
#
#
# BlingBling (Korea Band)
#                 (1)
#
#
# Blink Twice - Joy Oladokun (Song)
#                 (1)
#
#
# Blink-182
#                 (266)
#
#
# BLITZERS (Band)
#                 (2)
#
#
# Blitzkid (Band)
#                 (6)
#
#
# Blixa Bargeld (Musician)
#                 (12)
#
#
# BLK (Band)
#                 (3)
#
#
# Block B (Band)
#                 (1059)
#
#
# Blondie (Band)
#                 (23)
#
#
# Blood - The Middle East (Song)
#                 (1)
#
#
# Blood (Japan Band)
#                 (1)
#
#
# Blood // Water - Grandson (Song)
#                 (1)
#
#
# Blood On The Dance Floor
#                 (21)
#
#
# Blood Stain Child (Band)
#                 (1)
#
#
# Blood Under the Bridge - Frightened Rabbit (Song)
#                 (3)
#
#
# Bloodbuzz Ohio - The National (Song)
#                 (2)
#
#
# Bloodhound Gang (Band)
#                 (1)
#
#
# The Bloody Beetroots
#                 (1)
#
#
# Blossoms (Band)
#                 (22)
#
#
# Blow - Ke$ha (Music Video)
#                 (1)
#
#
# Blu-BiLLioN
#                 (1)
#
#
# Blue - Troye Sivan (Song)
#                 (9)
#
#
# Blue (Band)
#                 (2)
#
#
# The Blue Aces | The Aces (US Band)
#                 (1)
#
#
# Blue Bread Mold - Leslie Fish (Song)
#                 (1)
#
#
# Blue Caravan (Song)
#                 (2)
#
#
# Blue Light of the Flame - Dar Williams (Song)
#                 (1)
#
#
# Blue Monday - New Order (Song)
#                 (1)
#
#
# Blue Neighbourhood | Wild - Troye Sivan (Music Videos)
#                 (28)
#
#
# Blue Oyster Cult
#                 (12)
#
#
# The Blue Poptarts (Band)
#                 (9)
#
#
# Blue Song - Mint Royale (Music Video)
#                 (10)
#
#
# The Blue Stones (Band)
#                 (1)
#
#
# Blur (Band)
#                 (394)
#
#
# BLURRYFACE - Twenty One Pilots (Album)
#                 (145)
#
#
# Blutengel (Band)
#                 (3)
#
#
# BNK48
#                 (1)
#
#
# BNM BOYS (Band)
#                 (22)
#
#
# BoA (Musician)
#                 (39)
#
#
# Bob Dylan (Musician)
#                 (118)
#
#
# Body - Mother Mother (Song)
#                 (2)
#
#
# Body & Blood - clipping. (Music Video)
#                 (2)
#
#
# The Body Electric - Hurray For The Riff Raff (Song)
#                 (2)
#
#
# Body of Light (Band)
#                 (4)
#
#
# Бог проклятых - БИ-2 | Bog Proklyatikh - BI-2 (Music Video)
#                 (8)
#
#
# Бог проклятых - БИ-2 | Bog Proklyatikh - BI-2 (Song)
#                 (1)
#
#
# Bohemian Rhapsody - Queen (Song)
#                 (20)
#
#
# Bomb - AleXa (Music Video)
#                 (1)
#
#
# Bon Iver (Band)
#                 (1)
#
#
# Bon Jovi (Band)
#                 (471)
#
#
# 硬糖少女303 | BonBon Girls 303 (Band)
#                 (25)
#
#
# Bonelace Weaver (Traditional Song)
#                 (1)
#
#
# The Bones of an Idol - The New Pornographers (Song)
#                 (1)
#
#
# Bones UK (Band)
#                 (1)
#
#
# The Bonny Swans - Loreena McKennitt (Song)
#                 (1)
#
#
# BONUSbaby (Band)
#                 (1)
#
#
# Boogeyman - Johnny Hollow (Song)
#                 (1)
#
#
# Boom Trigger (Japan Band)
#                 (2)
#
#
# Бумбокс | Boombox (Band)
#                 (2)
#
#
# The Boomtown Rats
#                 (7)
#
#
# BORN (Band)
#                 (35)
#
#
# Born Never Asked - Laurie Anderson (Song)
#                 (1)
#
#
# Born This Way - Lady Gaga (Music Video)
#                 (2)
#
#
# Born to Die - Lana Del Rey (Album)
#                 (9)
#
#
# Born to Run - Bruce Springsteen (Album)
#                 (2)
#
#
# The BossHoss
#                 (1)
#
#
# Boston Manor (Band)
#                 (2)
#
#
# Bottom of the River - Delta Rae (Song)
#                 (4)
#
#
# Bottom of the River (Music Video)
#                 (2)
#
#
# Bowling For Soup (Band)
#                 (2)
#
#
# The Boxer - Simon & Garfunkel (Song)
#                 (3)
#
#
# Boy Band (TV)
#                 (6)
#
#
# Boy George (Musician)
#                 (26)
#
#
# Boy Story (Band)
#                 (34)
#
#
# BoybandPH (Band)
#                 (3)
#
#
# Boyfriend (Band)
#                 (90)
#
#
# BOYFRIENDS (Thailand Band)
#                 (1)
#
#
# boygenius (Band)
#                 (3)
#
#
# The Boys Are Back in Town (to kill you) - JerryTerry (Music Video)
#                 (2)
#
#
# Boys Boys Boys - Lady Gaga (Song)
#                 (1)
#
#
# Boys for Pele - Tori Amos (Album)
#                 (3)
#
#
# Boys generally Asian | BgA
#                 (13)
#
#
# Boys Like Girls (Band)
#                 (1)
#
#
# The Boys of Summer - Don Henley (Song)
#                 (2)
#
#
# Boys Republic (Band)
#                 (28)
#
#
# Boys World (US Band)
#                 (1)
#
#
# The Boyz (Korea Band)
#                 (3922)
#
#
# Boyzone (Band)
#                 (6)
#
#
# The Bramble Briar | In Bruton Town - Anonymous (Song)
#                 (1)
#
#
# Brand New (Band)
#                 (26)
#
#
# Brandy (You're a Fine Girl) - Looking Glass (Song)
#                 (13)
#
#
# Brave - Marillion (Album)
#                 (1)
#
#
# Brave - Sara Bareilles (Song)
#                 (1)
#
#
# Brave Girls (Korea Band)
#                 (1)
#
#
# 上线吧！华彩少年 | Bravo Youngsters! (TV)
#                 (2)
#
#
# Break It Yourself - Andrew Bird (Album)
#                 (2)
#
#
# BREAKERZ
#                 (13)
#
#
# Breaking Benjamin (Band)
#                 (105)
#
#
# Breaking Pangaea (Band)
#                 (1)
#
#
# Breathe Carolina
#                 (4)
#
#
# Bree Sharp (Musician)
#                 (1)
#
#
# Brett Eldredge (Musician)
#                 (1)
#
#
# Brian London (Musician)
#                 (11)
#
#
# Brides of Destruction (Band)
#                 (1)
#
#
# Bright Eyes (Band)
#                 (13)
#
#
# Бриллиантовые дороги | Brillyantoviye Dorogi - Gleb Samoyloff & The MATRIXX (Song)
#                 (1)
#
#
# Bring Me The Horizon
#                 (311)
#
#
# British Singers RPF
#                 (619)
#
#
# Britney Spears (Musician)
#                 (40)
#
#
# Britny Fox (Band)
#                 (1)
#
#
# Broadside (Band)
#                 (1)
#
#
# The Brobecks
#                 (97)
#
#
# BROCKHAMPTON (Band)
#                 (54)
#
#
# Broken Bride - Ludo (Album)
#                 (3)
#
#
# Broken Machine - Nothing But Thieves (Album)
#                 (1)
#
#
# Broken Social Scene
#                 (1)
#
#
# Bronte - Gotye (Music Video)
#                 (7)
#
#
# Bros (UK Band)
#                 (1)
#
#
# Brown-Eyed Girls (Band)
#                 (27)
#
#
# Bruce Springsteen & the E Street Band
#                 (28)
#
#
# Brun - Garmarna (Song)
#                 (1)
#
#
# Bruno Mars (Musician)
#                 (18)
#
#
# BT (Musician)
#                 (4)
#
#
# BTD (Before the Dawn) - Infinite (Music Video)
#                 (1)
#
#
# BTOB (Band)
#                 (622)
#
#
# Bubble Pop Electric - Gwen Stefani ft. Johnny Vulture
#                 (1)
#
#
# BUCK-TICK
#                 (310)
#
#
# Budka Suflera (Band)
#                 (1)
#
#
# Buffalo Springfield (Band)
#                 (6)
#
#
# bugAboo (Band)
#                 (1)
#
#
# BugLug
#                 (2)
#
#
# BUGVEL (Band)
#                 (1)
#
#
# Build God Then We'll Talk - Panic! at the Disco (Music Video)
#                 (1)
#
#
# Build That Wall (Zia's Theme) - Darren Korb (Song)
#                 (2)
#
#
# Bulldok (Band)
#                 (3)
#
#
# Bullet - Covenant (Song)
#                 (1)
#
#
# Bullet For My Valentine
#                 (8)
#
#
# Bump of Chicken (Band)
#                 (4)
#
#
# Buono! (Band)
#                 (1)
#
#
# Burn Witch Burn - Ego Likeness (Song)
#                 (1)
#
#
# bury a friend - Billie Eilish (Music Video)
#                 (3)
#
#
# Bury My Lovely - October Project (Music Video)
#                 (2)
#
#
# Burzum (Band)
#                 (23)
#
#
# Bus Stop - The Hollies (Song)
#                 (1)
#
#
# Bushes of Love - Bad Lip Reading (Song)
#                 (1)
#
#
# Bushido (Musician) RPF
#                 (18)
#
#
# Busker Busker (Band)
#                 (1)
#
#
# Busted (Band)
#                 (47)
#
#
# Busters (Band)
#                 (6)
#
#
# Butch Walker (Musician)
#                 (4)
#
#
# Butch Walker and the Let's-Go-Out-Tonites
#                 (1)
#
#
# Butcher Babies (Band)
#                 (1)
#
#
# BUTOUKAN
#                 (4)
#
#
# Butterfly - Rajaton (Song)
#                 (1)
#
#
# Butterfly Syndrome (Band)
#                 (1)
#
#
# Buzz (Korea Band)
#                 (99)
#
#
# BVCCI HAYNES
#                 (25)
#
#
# BVNDIT (Band)
#                 (12)
#
#
# BXW (Japan Band)
#                 (2)
#
#
# By and By - Caamp (Song)
#                 (1)
#
#
# By-Sexual (Band)
#                 (3)
#
#
# The Byrds (Band)
#                 (17)
#
#
# C-Clown
#                 (30)
#
#
# C-Pop
#                 (618)
#
#
# C-ute
#                 (9)
#
#
# The Cab (Band)
#                 (84)
#
#
# Cabinet Man - Lemon Demon (Song)
#                 (7)
#
#
# Cacophony (Band)
#                 (1)
#
#
# Cadaveria (Musician)
#                 (2)
#
#
# Cage the Elephant - Cage the Elephant (Album)
#                 (5)
#
#
# Cain's Offering
#                 (1)
#
#
# Cairokee (Band)
#                 (1)
#
#
# CALABRESE (Band)
#                 (1)
#
#
# Cali Gari
#                 (2)
#
#
# California - Mylène Farmer (Music Video)
#                 (1)
#
#
# Call Me - Blondie (Song)
#                 (1)
#
#
# 披荆斩棘的哥哥 | Call Me By Fire (TV)
#                 (133)
#
#
# Call Me Maybe - Carly Rae Jepsen (Music Video)
#                 (6)
#
#
# Call Me When You're Sober - Evanescence (Music Video)
#                 (1)
#
#
# Call the Ships to Port - Covenant (Song)
#                 (1)
#
#
# Calling Occupants of Interplanetary Craft - Klaatu (Song)
#                 (1)
#
#
# Calvin Harris (Musician)
#                 (5)
#
#
# Camila Cabello (Musician)
#                 (30)
#
#
# Can't Remember to Forget You - Shakira ft. Rihanna (Music Video)
#                 (1)
#
#
# Can't Stop Drinking About You - Otto Knows vs. Bebe Rexha (Song)
#                 (1)
#
#
# Canadian Idol RPF
#                 (26)
#
#
# Canadian Music RPF
#                 (654)
#
#
# Canadian Musician RPF (C6D)
#                 (6)
#
#
# CANARY (Band)
#                 (2)
#
#
# Cane Hill (Band)
#                 (1)
#
#
# CANIVAL (Band)
#                 (1)
#
#
# El Canto del Loco
#                 (1)
#
#
# Captain Fantastic and the Brown Dirt Cowboy - Elton John (Song)
#                 (1)
#
#
# Car Seat Headrest (Band)
#                 (4)
#
#
# Car Wash - Bruce Springsteen (Song)
#                 (2)
#
#
# Carach Angren (Band)
#                 (12)
#
#
# Caramella Girls (Virtual Band)
#                 (1)
#
#
# Carat (Japan Band)
#                 (2)
#
#
# Caravan Palace (Band)
#                 (4)
#
#
# Cardiacs (UK Band)
#                 (2)
#
#
# cardigan - Taylor Swift (Song)
#                 (18)
#
#
# Career of Evil - Blue Oyster Cult (Song)
#                 (1)
#
#
# Cargill - King Creosote (Song)
#                 (4)
#
#
# Carly Rae Jepsen (Musician)
#                 (6)
#
#
# Carnival Glass - Seanan McGuire (Song)
#                 (1)
#
#
# The Carnival Is Over - Dead Can Dance (Song)
#                 (2)
#
#
# The Carnival Is Over - The Seekers (Song)
#                 (3)
#
#
# Carnival of Rust - Poets of the Fall (Music Video)
#                 (3)
#
#
# Carolina - Harry Styles (Song)
#                 (7)
#
#
# The Carpenters (Band)
#                 (2)
#
#
# Carrie Underwood (Musician)
#                 (1)
#
#
# The Cars (Band)
#                 (6)
#
#
# Cartel (Band)
#                 (2)
#
#
# Cartography - Seanan McGuire (Song)
#                 (1)
#
#
# ...
#                 (1)
#
#
# Wasteland Baby - Hozier (Album)
#                 (6)
#
#
# The Water is Wide - Gerard Way (Song)
#                 (1)
#
#
# Watermelon Sugar - Harry Styles (Song)
#                 (13)
#
#
# Waterparks (Band)
#                 (827)
#
#
# We Appreciate Power - Grimes (Music Video)
#                 (2)
#
#
# We Are 1
#                 (1)
#
#
# We Are the Fury
#                 (2)
#
#
# We Are The Heroes - Litesound (Music Video)
#                 (2)
#
#
# We Are The In Crowd (Band)
#                 (32)
#
#
# 少年之名 | We Are Young (TV 2020)
#                 (22)
#
#
# We As Human (Band)
#                 (1)
#
#
# We Built This City - Starship (Song)
#                 (2)
#
#
# We Came As Romans (Band)
#                 (8)
#
#
# We Didn't Start the Fire - Billy Joel (Song)
#                 (1)
#
#
# We Go Up - NCT Dream (Music Video)
#                 (173)
#
#
# We The Kings (Band)
#                 (2)
#
#
# We Were the Same - Matt Maeson (Song)
#                 (1)
#
#
# Wednesday 13 (Band)
#                 (13)
#
#
# Wednesday Morning 3 A.M. - Simon & Garfunkel (Song)
#                 (2)
#
#
# Weeekly (Korea Band)
#                 (37)
#
#
# The Weeknd (Musician)
#                 (11)
#
#
# Ween (Band)
#                 (1)
#
#
# Weezer (Band)
#                 (53)
#
#
# WEi (Korea Band)
#                 (159)
#
#
# The Weight - The Band (Song)
#                 (2)
#
#
# Weird Al Yankovic (Musician)
#                 (12)
#
#
# Weki Meki (Band)
#                 (93)
#
#
# Welcome to Camp Averno - Sushi Soucy & August Greenwood (Song)
#                 (3)
#
#
# Welcome to the Black Parade - My Chemical Romance (Song)
#                 (19)
#
#
# Welle: Erdball
#                 (10)
#
#
# Wendy Trilogy - S. J. Tucker (Song Cycle)
#                 (6)
#
#
# Werewolf Bar Mitzvah - Donald Glover (Song)
#                 (1)
#
#
# Werewolves of London - Warren Zevon (Song)
#                 (5)
#
#
# West Coast (Minimal Remix) - The Young Professionals (Song)
#                 (1)
#
#
# Western Stars - Bruce Springsteen (Album)
#                 (1)
#
#
# Westlife
#                 (357)
#
#
# Wet Wet Wet (Band)
#                 (1)
#
#
# Wham! (Band)
#                 (12)
#
#
# What About Us - P!nk (Song)
#                 (1)
#
#
# What Else Is There? - Röyksopp (Music Video)
#                 (1)
#
#
# What Goes Around - Justin Timberlake (Music Video)
#                 (2)
#
#
# What It Feels Like for a Girl - Madonna (Music Video)
#                 (1)
#
#
# What the Water Gave Me - Florence + the Machine (Song)
#                 (3)
#
#
# What's It Gonna Be? - Shura (Music Video)
#                 (1)
#
#
# What's Your Mama's Name Child? - Tanya Tucker (Song)
#                 (4)
#
#
# Whataya Want From Me - Adam Lambert (Song)
#                 (1)
#
#
# Whatever You Want - Vienna Teng (Song)
#                 (5)
#
#
# Wheatus (Band)
#                 (2)
#
#
# Wheels On The Bus - Melanie Martinez (Music Video)
#                 (1)
#
#
# When Blackbirds Fly - Michael Franks (Song)
#                 (1)
#
#
# When Doves Cry - Prince (Song)
#                 (2)
#
#
# When Fallen Angels Fly - Patty Loveless (Song)
#                 (1)
#
#
# When The Day Met The Night - Panic! at the Disco (Song)
#                 (4)
#
#
# When You're Evil - Voltaire (Song)
#                 (2)
#
#
# Whenever It Rains - Aviators (Song)
#                 (1)
#
#
# Where Are You Now Patty - Lenny Green (Song)
#                 (3)
#
#
# Where Do You Go To (My Lovely)? - Peter Sarstedt (Song)
#                 (1)
#
#
# Where The Wild Roses Grow - Nick Cave & Kylie Minogue (Song)
#                 (2)
#
#
# Which Witch - Florence + the Machine (Song)
#                 (1)
#
#
# Виски - БИ-2 | Whiskey - BI-2 (Music Video)
#                 (3)
#
#
# Whiskey in Mind - Christian Kane (Song)
#                 (4)
#
#
# Whiskey in the Jar (Song)
#                 (3)
#
#
# Whiskey Lullaby - Brad Paisley & Alison Krauss
#                 (5)
#
#
# Whisper - VIXX LR (Music Video)
#                 (14)
#
#
# White Noise - FEMM (Song)
#                 (1)
#
#
# The White Stripes
#                 (21)
#
#
# White Trash Wedding - The Chicks (Song)
#                 (1)
#
#
# White Unicorn - Wolfmother (Song)
#                 (1)
#
#
# Whitesnake (Band)
#                 (10)
#
#
# The Who (Band)
#                 (260)
#
#
# Who Killed Amanda Palmer - Amanda Palmer (Album)
#                 (6)
#
#
# Who Wants to Live Forever - Queen (Song)
#                 (1)
#
#
# Whole Day Off - Oingo Boingo (Song)
#                 (1)
#
#
# Why Don't We (Band)
#                 (107)
#
#
# Wicked Girls - Seanan McGuire (Album)
#                 (11)
#
#
# Wicked Girls - Seanan McGuire (Song)
#                 (3)
#
#
# The Wife of Usher's Well (Traditional Ballad)
#                 (2)
#
#
# The Wiggles
#                 (10)
#
#
# Wilco
#                 (4)
#
#
# Wild Orchid Children (Band)
#                 (2)
#
#
# Wild World - Bastille (Album)
#                 (1)
#
#
# Wild Youth (Band)
#                 (2)
#
#
# Wildest Dreams - Taylor Swift (Music Video)
#                 (5)
#
#
# Will You Still Love Me Tomorrow? - Bryan Ferry (Music Video)
#                 (1)
#
#
# William Control (Band)
#                 (2)
#
#
# Willie o Winsbury - Anonymous (Song)
#                 (1)
#
#
# Willie of Winsbury (Child 100) - Anaïs Mitchell (Song)
#                 (2)
#
#
# The Willis Clan (Band)
#                 (1)
#
#
# willow - Taylor Swift (Song)
#                 (2)
#
#
# The Willow Maid - Erutan (Song)
#                 (4)
#
#
# The Wind - Cat Stevens (Song)
#                 (1)
#
#
# Windy Day - Oh My Girl (Music Video)
#                 (3)
#
#
# The Winery Dogs (Band)
#                 (1)
#
#
# Winger (Band)
#                 (4)
#
#
# Wings - Pixy (Music Video)
#                 (2)
#
#
# Wings | Paul McCartney and Wings (Band)
#                 (8)
#
#
# Wings Wetted Down - Blue Oyster Cult (Song)
#                 (1)
#
#
# Winner (Band)
#                 (1554)
#
#
# Winter Passing - The Academy Is... (Song)
#                 (2)
#
#
# Winter Song - Sara Bareilles (Music Video)
#                 (4)
#
#
# Winter Wonderland - Andrews Sisters (Song)
#                 (1)
#
#
# Winter Wonderland - Felix Bernard & Richard B. Smith (Song)
#                 (1)
#
#
# Winterreise - Franz Schubert (Song)
#                 (1)
#
#
# Wintersmith - Steeleye Span (Album)
#                 (1)
#
#
# Wintersun (Band)
#                 (5)
#
#
# Wiped Out! - The Neighbourhood (Song)
#                 (1)
#
#
# Wise Guys (Germany Band)
#                 (2)
#
#
# Wish You Were Here - Pink Floyd (Song)
#                 (2)
#
#
# Witch Hunt - Jack Off Jill (Song)
#                 (1)
#
#
# Witch of the Westmorland - Stan Rogers (Song)
#                 (3)
#
#
# With Confidence (Band)
#                 (10)
#
#
# With One Last Breath
#                 (1)
#
#
# Within Temptation (Band)
#                 (84)
#
#
# Within You - David Bowie (Song)
#                 (2)
#
#
# Without You - NCT U (Music Video)
#                 (35)
#
#
# WITZ | We In The Zone (Band)
#                 (10)
#
#
# Wiz Khalifa (Musician)
#                 (1)
#
#
# Wizzard (Band)
#                 (6)
#
#
# Woe Is Me (Band)
#                 (1)
#
#
# The Wolf - Phildel (Song)
#                 (1)
#
#
# Wolf Like Me - TV on the Radio (Song)
#                 (1)
#
#
# Wolfsheim (Band)
#                 (32)
#
#
# Woman - Harry Styles (Song)
#                 (33)
#
#
# Woman King (Song)
#                 (2)
#
#
# The Wombats (Band)
#                 (1)
#
#
# Wonder Girls (Band)
#                 (45)
#
#
# Wonderland - Natalia Kills (Song)
#                 (1)
#
#
# The Wondersmith and His Sons - Astronautalis (Song)
#                 (1)
#
#
# woo!ah! (Korea Band)
#                 (5)
#
#
# Wooden Girl ~Thousand Year Wiegenlied~ - Akuno-P (Song)
#                 (1)
#
#
# The Word Alive
#                 (1)
#
#
# Words - Skylar Grey (Song)
#                 (1)
#
#
# Work Song - Hozier (Music Video)
#                 (3)
#
#
# Work Song - Hozier (Song)
#                 (3)
#
#
# Workingman's Blues #2 - Bob Dylan (Song)
#                 (1)
#
#
# The World Is Not Enough - Garbage (Music Video)
#                 (4)
#
#
# World Order (Band)
#                 (1)
#
#
# Would That I - Hozier (Song)
#                 (1)
#
#
# Wozwald - Niru Kajitsu ft. flower (Song)
#                 (1)
#
#
# Wretched and Divine: The Story of the Wild Ones - Black Veil Brides (Album)
#                 (31)
#
#
# Written In Gray (Band)
#                 (1)
#
#
# WSTR (Band)
#                 (1)
#
#
# 无需要太多 - 张国荣 | Wu Shu Yao Tai Duo - Leslie Cheung (Song)
#                 (2)
#
#
# 五条人 | Wu Tiao Ren (Band)
#                 (52)
#
#
# X - Code Kunst ft. Lee Hi (Song)
#                 (2)
#
#
# X Factor (Italy) RPF
#                 (60)
#
#
# X Factor (UK) RPF
#                 (122)
#
#
# X Factor RPF
#                 (450)
#
#
# X JAPAN
#                 (340)
#
#
# X Libris - Talis Kimberley (Song)
#                 (1)
#
#
# X 玖少年团 | X-NINE (Band)
#                 (102)
#
#
# 燃烧吧少年! | X-Fire RPF
#                 (78)
#
#
# X1 (Korea Band)
#                 (2628)
#
#
# xaa-xaa (Band)
#                 (5)
#
#
# Xandria (Band)
#                 (1)
#
#
# Xdinary Heroes (Band)
#                 (16)
#
#
# Xibalba (Japan Band)
#                 (1)
#
#
# 十二星宿 | XII Constellations (Band)
#                 (2)
#
#
# Xiu Xiu (Band)
#                 (1)
#
#
# XOX (Japan Band)
#                 (1)
#
#
# XTRMST
#                 (1)
#
#
# XXXTentacion (Musician) RPF
#                 (6)
#
#
# Ya-ya-yah (Band)
#                 (13)
#
#
# Yamashita Tomohisa (Musician)
#                 (28)
#
#
# Yanni (Musician) RPF
#                 (1)
#
#
# The Yardbirds (Band)
#                 (20)
#
#
# The Yawning Grave - Lord Huron (Song)
#                 (2)
#
#
# YDPP (Band)
#                 (31)
#
#
# Yeah Yeah Yeahs
#                 (2)
#
#
# Year of the Cat - Al Stewart (Song)
#                 (1)
#
#
# Years & Years (Band)
#                 (56)
#
#
# Yellow Flicker Beat - Lorde (Song)
#                 (2)
#
#
# YELLOW FRIED CHICKENz
#                 (39)
#
#
# The Yellow Monkey (Band)
#                 (3)
#
#
# Yellowcard (Band)
#                 (5)
#
#
# Yelows Mob (Band)
#                 (2)
#
#
# Yes (Band)
#                 (26)
#
#
# 我心中尚未崩壞的地方 - 五月天 | The Yet Unbroken Part of My Heart - Mayday (Music Video)
#                 (1)
#
#
# Yeti (Japan Band)
#                 (1)
#
#
# YG Entertainment | YG Family
#                 (6892)
#
#
# YG Treasure Box (TV)
#                 (277)
#
#
# YHNEXT (Band)
#                 (32)
#
#
# 易安音乐社 | Yi An Musical (Band)
#                 (123)
#
#
# Ylvis RPF
#                 (557)
#
#
# Yngwie Malmsteen (Musician)
#                 (1)
#
#
# Yorushika (Band)
#                 (2)
#
#
# Yoshimi Battles the Pink Robots Pt. 1 - The Flaming Lips (Song)
#                 (1)
#
#
# Yoshiwara Lament (Song)
#                 (1)
#
#
# You - Pearl And The Beard (Song)
#                 (1)
#
#
# You and I - Dreamcatcher (Music Video)
#                 (2)
#
#
# Yoü And I - Lady Gaga (Song)
#                 (1)
#
#
# You Baby - Jackie Trent (Song)
#                 (1)
#
#
# You Belong to Me - Cat Pierce (Song)
#                 (1)
#
#
# You Belong With Me - Taylor Swift (Music Video)
#                 (2)
#
#
# You Belong With Me - Taylor Swift (Song)
#                 (4)
#
#
# You Belong With Me - University of Rochester Yellowjackets (Music Video)
#                 (12)
#
#
# You Can Call Me Al - Paul Simon (Song)
#                 (1)
#
#
# You Deserve Better - James Arthur (Song)
#                 (1)
#
#
# You Don't Know Me - Diane Schuur & B.B. King (Song)
#                 (1)
#
#
# You Don't Mess Around With Jim - Jim Croce (Song)
#                 (1)
#
#
# You In Me - K.A.R.D (Music Video)
#                 (1)
#
#
# You Make Me Feel - Cobra Starship (Music Video)
#                 (2)
#
#
# You Me At Six
#                 (272)
#
#
# You Oughta Know - Alanis Morrisette (Song)
#                 (2)
#
#
# You Stay Here - Richard Shindell (Song)
#                 (2)
#
#
# You Will Miss Me When I Burn - Soulsavers (Song)
#                 (1)
#
#
# You're At The Party - Lemon Demon (Song)
#                 (1)
#
#
# You're Gonna Go Far Kid - The Offspring (Song)
#                 (1)
#
#
# You're Not Sorry - Taylor Swift (Song)
#                 (2)
#
#
# You're So Vain - Carly Simon (Song)
#                 (2)
#
#
# You're Welcome - Jordan Fisher (Music Video)
#                 (1)
#
#
# YOU&I - IU (Music Video)
#                 (1)
#
#
# The Young Blood Chronicles - Fall Out Boy (Music Video)
#                 (77)
#
#
# Young Heretics (Band)
#                 (1)
#
#
# Young Love (Band)
#                 (9)
#
#
# Young the Giant (Band)
#                 (1)
#
#
# Young Thugs Club (Korea Band)
#                 (1)
#
#
# Young Veins
#                 (496)
#
#
# Youngblood - 5 Seconds Of Summer (Album)
#                 (21)
#
#
# Your Favorite Martian
#                 (17)
#
#
# YTC4LYF (Band)
#                 (1)
#
#
# 羽泉 | Yǔ Quán (Band)
#                 (18)
#
#
# Yulia - Wolf Parade (Music Video)
#                 (1)
#
#
# 夢みるアドレセンス | Yumemiru Adolescence
#                 (1)
#
#
# Yung Lean (Musician) RPF
#                 (1)
#
#
# Yungblud (Musician)
#                 (264)
#
#
# Z-Boys (Band)
#                 (3)
#
#
# Z-Girls (Band)
#                 (3)
#
#
# Z.Tao (Musician)
#                 (186)
#
#
# Zac Brown Band
#                 (1)
#
#
# Зажигать - БИ-2 | Zazhigat - BI-2 (Song)
#                 (1)
#
#
# ZE:A (Band)
#                 (62)
#
#
# Zemfira (Musician) RPF
#                 (37)
#
#
# Zendaya (Musician)
#                 (41)
#
#
# Zeromancer (Band)
#                 (2)
#
#
# Zhang Liyin (Musician)
#                 (6)
#
#
# Zi:Kill (Band)
#                 (2)
#
#
# Zico Chain
#                 (4)
#
#
# Zigzo (Band)
#                 (1)
#
#
# ZIZ (Band)
#                 (2)
#
#
# Зло - Кукрыниксы | Zlo - Kukryniksy (Song)
#                 (1)
#
#
# Zugezogen Maskulin
#                 (1)
#
#
# Зверь - Наутилус Помпилиус | Zver - Nautilus Pompilius (Song)
#                 (1)
#
#
# ZZ Top (Band)
#                 (1)

# %%
fandoms
# Out:
# {'&AUDITION Boys (Band)': 5,
#  '$uicideboy$ (Band)': 4,
#  'the 1 - Taylor Swift (Song)': 3,
#  '1 Trait Danger (Band)': 3,
#  '100 Gecs (Band)': 8,
#  '100 Monkeys': 2,
#  '백퍼센트 | 100 Percent (Band)': 13,
#  '娛樂百分百 | 100 Percent Entertainment (TV)': 511,
#  '100 Years - Five for Fighting (Song)': 2,
#  '12 Stones (Band)': 1,
#  '12012 (Band)': 7,
#  'The 13th Floor Elevators (Band)': 1,
#  '14U (Band)': 5,
#  '15& (Band)': 69,
#  '176BIZ (Japan Band)': 2,
#  '1950 - King Princess (Song)': 1,
#  '1952 Vincent Black Lightning (Song)': 2,
#  '1960s Music Scene RPF': 6078,
#  'The 1975 (Band)': 332,
#  '1989 - Taylor Swift (Album)': 5,
#  '1NB (Band)': 1,
#  '1PUNCH (Band)': 23,
#  '1TEAM (Band)': 32,
#  '1The9 (Band)': 47,
#  '1TYM': 5,
#  '1년 정거장 | One Year Station - G-Dragon (Song)': 1,
#  '21st Century Breakdown - Green Day (Album)': 11,
#  '24 Italian Art Songs and Arias': 2,
#  '24K (Band)': 36,
#  '250000 Miles - Patty Griffin (Song)': 1,
#  '2AM (Band)': 19,
#  '2Cellos': 26,
#  '2gether (US Band)': 7,
#  '#2Маши | #2Mashi (Band)': 21,
#  '2NE1': 219,
#  '2PM (Band)': 353,
#  '2wo (Band)': 2,
#  '2Z (Korea Band)': 2,
#  '30 Days - Never Shout Never (Song)': 1,
#  '30 Seconds to Mars': 746,
#  '365 Fresh - Triple H (Music Video)': 9,
#  "'39 - Queen (Song)": 2,
#  '3OH!3': 4,
#  '3YE (Korea Band)': 3,
#  "네시 | 4 O'Clock - RM & V (Song)": 3,
#  '4\'33" - John Cage (Song)': 21,
#  '+44 (Band)': 12,
#  '4minute (Band)': 75,
#  '4Ten (Band)': 1,
#  '4tune_UNIT': 2,
#  '5 Seconds of Summer (Band)': 10043,
#  '504 Plan': 1,
#  "The 51st Highland Division's Farewell to Sicily - Hamish Henderson (Song)": 1,
#  '5urprise (Band)': 9,
#  '6/10 - Dodie Clark (Song)': 3,
#  '69 Eyes': 15,
#  '6969 - Ninja Sex Party (Song)': 22,
#  '7 MEN 侍 | 7 MEN Samurai (Band)': 40,
#  '74 - Itoki Hana & Toby Fox (Song)': 1,
#  '747 (Strangers In The Night) - Saxon (Song)': 1,
#  '777 | Triple 7 (Korea Band)': 1,
#  '7WEST': 1,
#  '8.32 - Luna (Song)': 1,
#  '867-5309/Jenny - Tommy Tutone (Song)': 2,
#  '88 Lines About 44 Women - The Nails (Song)': 1,
#  '8P-SB (Band)': 5,
#  '9 to 5 - Dolly Parton (Song)': 3,
#  '98 Degrees': 3,
#  '99 Luftballons | 99 Red Balloons - Nena (Song)': 8,
#  '999 (Band)': 2,
#  '9GOATS BLACK OUT': 14,
#  '9x9 | NINE BY NINE (BAND)': 3,
#  'A Pink (Band)': 118,
#  'А что нам надо? - СерьГа | A shto nam nado? - SerGa (Song)': 1,
#  'a-ha (Band)': 3,
#  'A-Jax (Band)': 2,
#  'A-Teens (Sweden Band)': 1,
#  'A.B.C.-Z': 57,
#  'A.C.E (Beat Interactive Band)': 1280,
#  'A.cian (Band)': 2,
#  'A.DE (Band)': 1,
#  'A.I.VOICE': 1,
#  'A.KOR': 3,
#  'A$AP Mob': 1,
#  'A1': 2,
#  'A6P (Band)': 2,
#  'A9 | Alice Nine (Band)': 471,
#  'AAA (Band)': 35,
#  'Aaliyah (Musician) RPF': 3,
#  'AB6IX (Band)': 634,
#  'ABBA (Band)': 33,
#  'Abbey Death (Band)': 1,
#  'ABC (UK Band)': 3,
#  'Abingdon Boys School (Band)': 7,
#  'Abney Park': 4,
#  "Abraham's Daughter - Arcade Fire (Song)": 6,
#  'Abù - Bandabardò (Song)': 1,
#  'AC/DC (Band)': 23,
#  'The Academy Is...': 985,
#  'Ace of Base': 1,
#  'Ace of Spades (Japan Band)': 1,
#  "Acele - Carla's Dreams (Song)": 1,
#  'Acid Android (Band)': 3,
#  'Acid Black Cherry': 10,
#  'Act Series - The Dear Hunter (Albums)': 4,
#  'Adam - Alex G (Song)': 1,
#  'Dat Adam (Band)': 1,
#  'Adam Ant (Musician)': 5,
#  'Adam Lambert (Musician)': 4264,
#  'Adam Levine (Musician)': 171,
#  'Adam Young (Musician) RPF': 19,
#  'ADAMS (Band)': 7,
#  'Addict With a Pen - Twenty One Pilots (Song)': 2,
#  'Addicted - PIXY (Music Video)': 2,
#  'Addicted to You - Avicii (Music Video)': 8,
#  'Addiction (Japan Band)': 1,
#  'Adele (Musician)': 5,
#  'Adema (Band)': 1,
#  'Adonai - Lord of the Lost (Song)': 1,
#  'Adore You - Harry Styles (Song)': 48,
#  'Adrenaline Mob (Band)': 1,
#  'A ぇ! Group! | Ae! Group! (Band)': 3,
#  'Aelonia (Band)': 2,
#  'Aerosmith (Band)': 22,
#  'Aespa (Band)': 407,
#  'Aeterno - Aviators (Album)': 2,
#  'AFI (Band)': 323,
#  'Africa - Rose Laurens (Song)': 1,
#  'Africa - Toto (Song)': 2,
#  'After School (Band)': 58,
#  'After School Club (TV)': 9,
#  'After the Gold Rush - Neil Young (Song)': 2,
#  'After the Rain Has Fallen - Sting (Song)': 1,
#  'Afterhours (Band)': 147,
#  'Against Me!': 9,
#  'Against the Current (Band)': 4,
#  'Агата Кристи | Agatha Christie (Band)': 61,
#  '特務J - 蔡依林 | Agent J - Jolin Tsai (Song)': 1,
#  'Agnete og Havmanden (Song)': 2,
#  'The Agonist': 1,
#  'Ангел С Грязным Лицом - Кукрыниксы | Ahngel C Gryznym Litsom - Kukryniksy (Song)': 1,
#  '愛狂います。| Aicle.': 2,
#  'АИГЕЛ | AIGEL (Band)': 1,
#  'AILE (Band)': 1,
#  'Ailee (Musician)': 20,
#  'Ailein Duinn - Karliene (Song)': 1,
#  'Aims - Vienna Teng (Album)': 2,
#  "Ain't No Sunshine - Bill Withers (Song)": 1,
#  'Aiolin (Band)': 1,
#  'Airplane (Korea Band)': 1,
#  'Airwaves (Song)': 1,
#  'AIsingers': 1,
#  'AJJ (Band)': 1,
#  'AJR (Band)': 22,
#  'Ak Dong Club': 1,
#  'AKB48': 257,
#  'AKB48 & Related Fandoms': 697,
#  'Akdong Musician': 23,
#  'Alabama 3': 2,
#  'Alabama Motel Room - Matthew Good Band (Song)': 1,
#  'Aladdin Sane - David Bowie (Album)': 1,
#  'Alamat (Band)': 13,
#  'Alanis Morissette (Musician)': 3,
#  'Alcest (Band)': 1,
#  'Aldious (Band)': 1,
#  'Alejandro - Lady Gaga (Music Video)': 2,
#  'Alesana (Band)': 1,
#  'Alestorm (Band)': 3,
#  'Alexandros (Japan Band)': 1,
#  'Ансамбль Александрова | Alexandrov Ensemble | Red Army Choir': 30,
#  'Ali Project (Band)': 1,
#  'Alibi - Dessa (Song)': 1,
#  'Alice - The Mechanisms (Song)': 2,
#  'Alice - Tom Waits (Album)': 1,
#  'Alice Cooper (Band)': 1,
#  'Alice Cooper (Musician) RPF': 39,
#  'Alice in Chains': 111,
#  "Alice's Restaurant - Arlo Guthrie (Song)": 1,
#  'Alicia Keys (Musician)': 3,
#  "Aliene Ma'riage (Band)": 1,
#  'Alkaline Trio (Band)': 68,
#  'All Along the Watchtower (Song)': 1,
#  'ALL CITY STEPPERS (Band)': 2,
#  'All Eyes On Me - Bo Burnham (Song)': 5,
#  '以团之名 | All for One (TV)': 20,
#  'All I Want - Emma Bale (Song)': 1,
#  '걸어 | All in - Monsta X (Music Video)': 56,
#  'All Souls Night - Loreena McKennitt (Song)': 2,
#  'All This Bad Blood - Bastille (Album)': 4,
#  'All Time Low (Band)': 1758,
#  'All Too Well - Taylor Swift (Song)': 1,
#  'All-American Rejects': 83,
#  'Alleluia - Dar Williams (Song)': 3,
#  'Allen Mack Myers Moore (Band)': 3,
#  'Allison Iraheta (Musician)': 8,
#  'ALLS-GIRL (Korea Band)': 1,
#  'The Almost': 1,
#  'Alone - Alan Walker (Music Video)': 1,
#  'ALPHA (Korea Band)': 1,
#  '알파벳 | AlphaBAT': 5,
#  'alt-J (Band)': 1,
#  'Alter Bridge': 4,
#  'Alternative Girlfriend - The Barenaked Ladies (Song)': 1,
#  'The Altogether (Band)': 4,
#  'ALvino (Band)': 2,
#  'Am Donaustrande - Brahms (Song)': 1,
#  'Am I the Only One? - Dierks B Bentley (Song)': 1,
#  'Amanda Lopiccolo (Musician)': 1,
#  'Amanda Palmer (Musician)': 20,
#  "Les amants d'un jour - Edith Piaf (Song)": 1,
#  'Amaranthe (Band)': 4,
#  'The Amazing Devil (Band)': 15,
#  'Ambeon (Band)': 1,
#  'America - Simon & Garfunkel (Song)': 1,
#  'America Fuck Yeah! - Team America (Song)': 1,
#  "America's Suitehearts - Fall Out Boy (Music Video)": 66,
#  'American Idiot - Green Day (Album)': 54,
#  'American Murder Song - Various (Album)': 18,
#  'American Oxygen - Rihanna (Music Video)': 1,
#  'American Pie - Don McLean (Song)': 2,
#  'American Soldier - Toby Keith (Song)': 1,
#  'Americano - Lady Gaga (Song)': 1,
#  'Amici di Maria de Filippi (TV) RPF': 3,
#  'The Amity Affliction': 5,
#  'Amnesia Was Her Name - Lemon Demon (Song)': 2,
#  'Amon Amarth (Band)': 3,
#  'Amurekimuri (Band)': 1,
#  'An Hini A Garan - Denez Prigent (Song)': 1,
#  'Ana Ng - They Might Be Giants (Song)': 1,
#  'Anaal Nathrakh (Band)': 1,
#  'Anatomy of a Murder - Duke Ellington (Album)': 1,
#  'Anavitória (Band)': 1,
#  'Anberlin': 1,
#  'And the Band Played Waltzing Matilda - Eric Bogle (Song)': 1,
#  'And You Give - Matthew Barber (Music Video)': 1,
#  'Andrew Bird & the Mysterious Production of Eggs - Andrew Bird (Album)': 4,
#  'Andrew Hozier-Byrne (Musician)': 184,
#  'Andrew in Drag - The Magnetic Fields (Song)': 3,
#  'Andrew W. K. (Musician)': 1,
#  "Andy You're A Star - The Killers (Song)": 3,
#  'Angdreville | ADV': 5,
#  'Angel Of Small Death & The Codeine Scene - Hozier (Song)': 1,
#  'Angelo (Band)': 29,
#  'Angels & Airwaves': 26,
#  'Angie Baby - Helen Reddy (Song)': 2,
#  'Angra (Band)': 6,
#  'Angus & Julia Stone': 1,
#  'The Animals (Band)': 1,
#  'Anli Pollicino': 8,
#  'Anna Blue (Musician)': 1,
#  'Annan Water (Traditional Ballad)': 2,
#  'Die Another Day - Madonna (Music Video)': 1,
#  'ANS (Korea Band)': 2,
#  'Antenna Angels (Band)': 2,
#  'Anteros (Band)': 5,
#  'Anthem Lights (Band)': 1,
#  'Anthrax (US Band)': 77,
#  'Antic Cafe (Band)': 12,
#  'Antichrist Superstar - Marilyn Manson (Album)': 12,
#  'Die Antwoord (Band)': 3,
#  'AnyBand': 5,
#  'AOA | Ace of Angels': 83,
#  'ApeCrime (Band)': 1,
#  'Apex - Ky Rodgers (Song)': 1,
#  'Aphex Twin': 3,
#  'Aphrodisiac - IAMX (Song)': 1,
#  'Apocalyptica (Band)': 93,
#  'Appelle mon numéro - Mylène Farmer (Music Video)': 1,
#  'Appetite of a People-Pleaser - GHOST | GHOST and Pals ft. v4 flower (Song)': 1,
#  'Apple Candy - Ben Lee (Song)': 1,
#  'Apple.B (Band)': 1,
#  "L'apprenti sorcier | The Sorcerer's Apprentice - Paul Dukas (Song)": 1,
#  'April (Band)': 10,
#  'April Come She Will - Simon & Garfunkel (Song)': 3,
#  'Aquarium - Camille Saint-Saens (Song)': 1,
#  'Aquarium (Russia Band)': 7,
#  'Arashi (Band)': 6946,
#  'Arcade Fire (Band)': 3,
#  'Arcadia (UK Band)': 51,
#  'Arch Enemy (Band)': 1,
#  'Archaeopteryx - Lemon Demon (Song)': 1,
#  'The ArchAndroid - Janelle Monáe': 14,
#  'Architects (UK Band)': 7,
#  'Arctic Monkeys': 717,
#  'Area 11': 15,
#  'Arege (Band)': 1,
#  'The Arena - Lindsey Stirling (Music Video)': 2,
#  'Argon (Korea Band)': 1,
#  'Ari Hest (Musician)': 1,
#  'Ария | Aria (Russia Band)': 26,
#  'Ariana Grande (Musician)': 72,
#  'Aristocrat - Poppy (Song)': 1,
#  'The Ark (Korea Band)': 7,
#  'Arlequin (Japan Band)': 4,
#  'Arma Angelus': 5,
#  'The Arrogant Worms': 1,
#  'Артерия | Arteria (Band)': 1,
#  'Артур Беркут | Arthur Berkut (Musician)': 1,
#  'Arven (Band)': 1,
#  'Die Ärzte': 50,
#  'As December Falls (Band)': 1,
#  'As It Is (Band)': 83,
#  'As it Was - Hozier (Song)': 1,
#  'As the World Caves In - Matt Maltese (Song)': 3,
#  'As the World Falls Down - David Bowie (Music Video)': 2,
#  'Aserejé | The Ketchup Song - Las Ketchup (Song)': 1,
#  'Ashestoangels (Band)': 1,
#  'Ashlee Simpson (Musician)': 15,
#  'Ashley Dzerigian (Musician)': 21,
#  'Asia (UK Band)': 1,
#  'ASIAN KUNG-FU GENERATION (Band)': 1,
#  'Aska - unterART (Song)': 1,
#  'Asking Alexandria (Band)': 55,
#  "L'Assasymphonie - Florent Mothe (Song)": 4,
#  'Assimilate (2019)': 1,
#  'ASTRO (Band)': 2215,
#  'Astronaut - Amanda Palmer (Song)': 4,
#  'At the Gates (Band)': 1,
#  '新しい学校のリーダーズ | Atarashii Gakkou no Leaders (Band)': 1,
#  'ATEEZ (Band)': 11089,
#  'Athena - CircusP & CrusherP (Song)': 1,
#  'Atlantic City - Bruce Springsteen (Song)': 5,
#  'Atomic Copper Claw - Lemon Demon (Song)': 1,
#  'Atomic Kitten (Band)': 1,
#  'Atreyu (Band)': 4,
#  'Attack Attack! (Band)': 14,
#  'Attila (Band 2005)': 2,
#  'Audioslave (Band)': 20,
#  'august - Taylor Swift (Song)': 21,
#  'Augustana (Band)': 1,
#  'АукцЫон | Auktyon (Band)': 1,
#  'Aural Vampire': 1,
#  'AURORA (Norway Musician)': 4,
#  'Austin - Blake Shelton (Song)': 2,
#  'Austin & Ally RPF': 19,
#  'Austin Mahone (Musician)': 11,
#  'Australian Idol RPF': 2,
#  "Autumn's Here - Hawksley Workman (Song)": 1,
#  'Avalon - Roxy Music (Album)': 1,
#  'Avantasia (Band)': 35,
#  'Avatar (Sweden Band)': 43,
#  'AvelCain (Band)': 1,
#  'Avenged Sevenfold': 397,
#  'Avril Lavigne (Musician)': 17,
#  'AWS (Band)': 1,
#  'Axel F - Crazy Frog (Music Video)': 3,
#  'Axl Rose (Musician)': 31,
#  'Aya (Musician)': 1,
#  'Ayabie (Band)': 47,
#  'Ayreon (Band)': 3,
#  'Ayria (Band)': 1,
#  'Ayumi Hamasaki (Musician)': 1,
#  'AZALEA (Japan Band)': 1,
#  'Aztec Camera (Band)': 1,
#  'The B-52s (Band)': 1,
#  'B.A.P': 2232,
#  'B.I.G | Boys in Groove': 45,
#  'B.I.Shadow': 15,
#  'B.O.Y (Korea Band)': 16,
#  'B1A4': 165,
#  'B5 (US Band)': 1,
#  'Babe - Sugarland ft. Taylor Swift (Music Video)': 2,
#  'Babes in Toyland (Band)': 1,
#  'Babooshka - Kate Bush (Song)': 1,
#  "Baby It's Cold Outside - Frank Loesser (Song)": 3,
#  'Baby Shark - Pingfong (Song)': 1,
#  "Baby You're a Rich Man - Beatles (Song)": 1,
#  'BabyKingdom (Band)': 1,
#  'BABYMETAL': 25,
#  'Babyshambles (Band)': 3,
#  'Des Baches Wiegenlied - Franz Schubert (Song)': 2,
#  'The Back Seat of My Car - Linda McCartney and Paul McCartney (Song)': 1,
#  'Back to December - Taylor Swift (Song)': 1,
#  'The Background Noise - IAMX (Song)': 1,
#  'Backstreet Boys': 1442,
#  'Backstreets - Bruce Springsteen (Song)': 2,
#  'Bad - Michael Jackson (Music Video)': 10,
#  'Bad at Love - Halsey (Music Video)': 1,
#  'Bad Bad Leroy Brown - Jim Croce (Song)': 1,
#  'Bad Blood - Taylor Swift (Music Video)': 65,
#  'Bad Girl - Madonna (Music Video)': 6,
#  'Bad Idea - Moon Bin & Sanha (Music Video)': 1,
#  'Bad Love - Key (Music Video)': 1,
#  'Bad Romance - Lady Gaga (Music Video)': 2,
#  'Bad Suns (Band)': 3,
#  'Badflower (Band)': 11,
#  'Badlands - Halsey (Album)': 21,
#  'BAE173 (Band)': 47,
#  'Bagger 288 - Rathergood (Song)': 1,
#  "Bagman's Gambit - The Decemberists": 1,
#  'BAISER (Band)': 1,
#  'Ball Cap - Mother Mother (Song)': 2,
#  'The Ballad of Lucy Jordan - Marianne Faithfull (Song)': 1,
#  'Ballad of Mona Lisa - Panic! At the Disco (Music Video)': 3,
#  'The Ballad of Mona Lisa - Panic! at the Disco (Song)': 2,
#  "The Ballad of Tim Horton's - The Arrogant Worms (Song)": 1,
#  'Ballistik Boyz from Exile Tribe (Band)': 7,
#  'Ballroom Blitz - Sweet (Song)': 1,
#  'Banana Man - Tally Hall (Song)': 1,
#  'Bananarama (Band)': 1,
#  'The Band (Band 1968)': 24,
#  'The Band (Canada Band)': 1,
#  'BAND-MAID (Band)': 5,
#  'Bandom': 56377,
#  'Bang Bang! (2014)': 1,
#  'Bangarang - Skrillex (Music Video)': 2,
#  'The Bangles (Band)': 1,
#  '방탄소년단 | Bangtan Boys | BTS': 169903,
#  "The Bard's Song (In the Forest) - Blind Guardian (Song)": 1,
#  'Barenaked Ladies (Band)': 5,
#  "Barrett's Privateers (Song)": 7,
#  'Barriers - Frank Iero and the Future Violents (Album)': 2,
#  'Barry Manilow (Musician)': 3,
#  'Bars and Melody (Band)': 2,
#  'Barton Hollow - The Civil Wars (Song)': 1,
#  'The Baseballs (Band)': 8,
#  'Bastille (Band)': 498,
#  'Bat Out of Hell Trilogy - Meat Loaf (Albums)': 2,
#  'BatAAR (Band)': 2,
#  'Bathory (Band)': 1,
#  'Battle (Korea Band)': 2,
#  'Bauhaus': 10,
#  'Baumkuchen End - E ve (Music Video)': 6,
#  'Bay City Rollers (Band)': 1,
#  'BDC | Boys Da Capo (Band)': 20,
#  'Be Alright - Dean Lewis (Song)': 1,
#  'Be.A (Band)': 1,
#  'The Beach Boys (Band)': 17,
#  'Beady Eye (Band)': 7,
#  'Bears in Trees (Band)': 3,
#  'Beartooth (Band)': 2,
#  'The Beast Inside - My Enemies and I (Album)': 1,
#  'Beastie Boys (Band)': 12,
#  'Beat For Beat (TV) RPF': 1,
#  'Beat the Champ - The Mountain Goats (Album)': 5,
#  'BeatBurger (Band)': 2,
#  'Beatcats (Band)': 1,
#  'The Beatles (Band)': 5118,
#  'Beautiful - Monsta X (Music Video)': 17,
#  'Beautiful Ghosts - Taylor Swift (Song)': 1,
#  'Beautiful Liar - Shakira & Beyoncé (Song)': 1,
#  'Beautiful Liar - VIXX LR (Music Video)': 21,
#  'Beautiful Pain - BTOB (Song)': 1,
#  'Beautiful Trauma - P!nk (Music Video)': 1,
#  'Bebe Rexha (Musician)': 12,
#  'BEcause - Dreamcatcher (Music Video)': 1,
#  'Because the Internet - Childish Gambino (Album)': 1,
#  'Beck (Musician)': 4,
#  'Becky G (Musician) RPF': 5,
#  'BECZ (Band)': 1,
#  'Bed of Roses - Bon Jovi (Song)': 1,
#  'Bedstead Men - Flanders and Swann (Song)': 1,
#  'Bee Gees (Band)': 5,
#  'The Beekeeper - Tori Amos (Album)': 1,
#  'Beenzino (Musician)': 1,
#  'Before You Exit (Band)': 2,
#  'Begin Again - Taylor Swift (Music Video)': 3,
#  'Begin Again - Taylor Swift (Song)': 2,
#  'Behemoth (Band)': 13,
#  'Behind Blue Eyes - The Who (Song)': 3,
#  'Behind The Scenes - Francesca Battistelli (Song)': 1,
#  'Beirut (Band)': 2,
#  'BEJ48 (Band)': 75,
#  'Bele Doette (Song)': 2,
#  'Believer - Imagine Dragons (Song)': 1,
#  'Belle and Sebastian': 1,
#  'Bellyache - Billie Eilish (Song)': 4,
#  'Belum Tidur - Hindia ft. Sal Priadi (Music Video)': 1,
#  'Ben Folds (Musician)': 1,
#  'Ben Howard (Musician) RPF': 1,
#  'Ben&Ben (Band)': 1,
#  'The Bends - Doomtree (Song)': 1,
#  'Beovizija RPF': 6,
#  "Beretta - Carla's Dreams (Song)": 1,
#  'Berry Bell (Band)': 1,
#  'Berry Good (Band)': 6,
#  'Berryz Koubou': 9,
#  'The Best Ever Death Metal Band in Denton - The Mountain Goats (Song)': 4,
#  'Best of the Black President - Fela Kuti (Album)': 2,
#  'The Best Song Ever - Gabrielle Aplin': 3,
#  'Best Song Ever - One Direction (Music Video)': 146,
#  'BESTie (Band)': 4,
#  'Better Oblivion Community Center (Band)': 1,
#  'Better Than I Know Myself - Adam Lambert (Music Video)': 8,
#  'Betty - Brooke Fraser (Music Video)': 1,
#  'betty - Taylor Swift (Song)': 26,
#  'Between Raising Hell and Amazing Grace - Big & Rich (Music Video)': 1,
#  'Beulah - John Paul White (Album)': 1,
#  'Beyoncé Knowles (Musician)': 35,
#  'Beyond (Band)': 13,
#  'Beyond Metropolis - Shriekback (Song)': 2,
#  'Beyond My Control - Mylène Farmer (Music Video)': 1,
#  'Beyond the Veil - Lindsey Stirling (Music Video)': 1,
#  'BEYOOOOONDS (Band)': 48,
#  'БИ-2 | BI-2 (Band)': 52,
#  'Библиотека Просперо | Biblioteka Prospero (Band)': 1,
#  'La bicyclette - Yves Montand (Album)': 1,
#  'Le bien qui fait mal - Mozart Opera Rock (Song)': 1,
#  'The Bifrost Incident - The Mechanisms (Album)': 181,
#  'Big Bad Bosses (Band)': 1,
#  'Big Bang (Band)': 2534,
#  'Big Byung (Band)': 6,
#  'Big Enough - Kirin J Callinan ft. Alex Cameron & Molly Lewis & Jimmy Barnes (Music Video)': 2,
#  'Big Iron - Marty Robbins (Song)': 4,
#  'Big Russian Boss (Musician)': 8,
#  'Big Science - Laurie Anderson (Song)': 1,
#  'Big Sean (Musician) RPF': 1,
#  'Big Time Rush (Band)': 284,
#  '大波浪 | THE BIG WAVE (Band)': 79,
#  'BIGFLO': 23,
#  'Bigflo & Oli (Band)': 1,
#  'The Bigfoot Scenic Byway - Lenny Green (Song)': 1,
#  'Bigfoot Stole My Baby - John Lilly (Song)': 1,
#  'BIGSTAR (Band)': 18,
#  'Bikini Kill (Band)': 3,
#  'Billie Eilish (Musician)': 45,
#  'Billy Idol (Musician)': 5,
#  'Billy Talent (Band)': 6,
#  'Birdhouse in Your Soul - They Might Be Giants (Music Video)': 1,
#  'Birdhouse in Your Soul - They Might Be Giants (Song)': 5,
#  'Birdy (Musician)': 3,
#  'Birthday - All Time Low (Song)': 1,
#  'The Birthday Massacre (Band)': 1,
#  'The Birthday Party (Band)': 10,
#  '美流沙女 | Birushana (1995 Soleil Band)': 1,
#  'BiS | Brand-new idol Society (Band)': 1,
#  'BiSH | Brand-new idol SHiT (Band)': 1,
#  '美少年 | Bishounen (Band)': 4,
#  'Bitch Better Have My Money - Rihanna (Music Video)': 2,
#  'The Bix Beiderbecke Legend - Bix Beiderbecke (Album)': 1,
#  'Bizarre Love Triangle - New Order (Song)': 1,
#  'Bizzy Montana (Musician)': 1,
#  'Björk (Musician)': 2,
#  "Black 'N Blue (US Band)": 4,
#  'Black Cards (Band)': 40,
#  'Black Coffee - The Careless Lovers (Music Video)': 1,
#  'The Black Crowes (Band)': 1,
#  'Black Eyed Peas (Band)': 2,
#  'Black Eyes - David Wirsig (Song)': 1,
#  'Black Flag (Band)': 4,
#  'Black Gene for the Next Scene (Band)': 6,
#  'The Black Keys (Band)': 2,
#  'Black Klaxon | Astaria (Band)': 1,
#  'Black Oxide - Lord of the Lost ft. Scarlet Dorn (Song)': 1,
#  'Black Parade - My Chemical Romance (Album)': 58,
#  'Black Rebel Motorcycle Club': 5,
#  'Black Ring Dreams (Band)': 1,
#  'Black Sabbath': 10,
#  'The Black Satans': 1,
#  'Black Sheep - Gin Wigmore (Song)': 1,
#  'THE BLACK SWAN (Band)': 1,
#  'Black Swan (Korea Band)': 2,
#  'Black Veil Brides': 625,
#  'Black-Dove (January) - Tori Amos (Song)': 1,
#  'BLACK6IX (Band)': 2,
#  'BlackACE (China Band)': 22,
#  'Blackfield (Band)': 1,
#  'The Blackout (Band)': 3,
#  'BLACKPINK (Band)': 2712,
#  'Blah Blah (Korea Band)': 1,
#  'Blake Shelton (Musician)': 305,
#  'BLANC7 (Band)': 8,
#  'Blank Space - Taylor Swift (Music Video)': 11,
#  'Blank Space - Taylor Swift (Song)': 1,
#  'Blaqk Audio': 4,
#  'Bleachers (Band)': 4,
#  'Bleed in Me - Obscure Sphinx (Song Cycle)': 1,
#  'Bleeding Me - Metallica (Song)': 1,
#  'Blessthefall (Band)': 7,
#  'Blind Channel (Band)': 514,
#  'Blind Guardian (Band)': 3,
#  'Blind Melon': 30,
#  'BlingBling (Korea Band)': 1,
#  'Blink Twice - Joy Oladokun (Song)': 1,
#  'Blink-182': 266,
#  'BLITZERS (Band)': 2,
#  'Blitzkid (Band)': 6,
#  'Blixa Bargeld (Musician)': 12,
#  'BLK (Band)': 3,
#  'Block B (Band)': 1059,
#  'Blondie (Band)': 23,
#  'Blood - The Middle East (Song)': 1,
#  'Blood (Japan Band)': 1,
#  'Blood // Water - Grandson (Song)': 1,
#  'Blood On The Dance Floor': 21,
#  'Blood Stain Child (Band)': 1,
#  'Blood Under the Bridge - Frightened Rabbit (Song)': 3,
#  'Bloodbuzz Ohio - The National (Song)': 2,
#  'Bloodhound Gang (Band)': 1,
#  'The Bloody Beetroots': 1,
#  'Blossoms (Band)': 22,
#  'Blow - Ke$ha (Music Video)': 1,
#  'Blu-BiLLioN': 1,
#  'Blue - Troye Sivan (Song)': 9,
#  'Blue (Band)': 2,
#  'The Blue Aces | The Aces (US Band)': 1,
#  'Blue Bread Mold - Leslie Fish (Song)': 1,
#  'Blue Caravan (Song)': 2,
#  'Blue Light of the Flame - Dar Williams (Song)': 1,
#  'Blue Monday - New Order (Song)': 1,
#  'Blue Neighbourhood | Wild - Troye Sivan (Music Videos)': 28,
#  'Blue Oyster Cult': 12,
#  'The Blue Poptarts (Band)': 9,
#  'Blue Song - Mint Royale (Music Video)': 10,
#  'The Blue Stones (Band)': 1,
#  'Blur (Band)': 394,
#  'BLURRYFACE - Twenty One Pilots (Album)': 145,
#  'Blutengel (Band)': 3,
#  'BNK48': 1,
#  'BNM BOYS (Band)': 22,
#  'BoA (Musician)': 39,
#  'Bob Dylan (Musician)': 118,
#  'Body - Mother Mother (Song)': 2,
#  'Body & Blood - clipping. (Music Video)': 2,
#  'The Body Electric - Hurray For The Riff Raff (Song)': 2,
#  'Body of Light (Band)': 4,
#  'Бог проклятых - БИ-2 | Bog Proklyatikh - BI-2 (Music Video)': 8,
#  'Бог проклятых - БИ-2 | Bog Proklyatikh - BI-2 (Song)': 1,
#  'Bohemian Rhapsody - Queen (Song)': 20,
#  'Bomb - AleXa (Music Video)': 1,
#  'Bon Iver (Band)': 1,
#  'Bon Jovi (Band)': 471,
#  '硬糖少女303 | BonBon Girls 303 (Band)': 25,
#  'Bonelace Weaver (Traditional Song)': 1,
#  'The Bones of an Idol - The New Pornographers (Song)': 1,
#  'Bones UK (Band)': 1,
#  'The Bonny Swans - Loreena McKennitt (Song)': 1,
#  'BONUSbaby (Band)': 1,
#  'Boogeyman - Johnny Hollow (Song)': 1,
#  'Boom Trigger (Japan Band)': 2,
#  'Бумбокс | Boombox (Band)': 2,
#  'The Boomtown Rats': 7,
#  'BORN (Band)': 35,
#  'Born Never Asked - Laurie Anderson (Song)': 1,
#  'Born This Way - Lady Gaga (Music Video)': 2,
#  'Born to Die - Lana Del Rey (Album)': 9,
#  'Born to Run - Bruce Springsteen (Album)': 2,
#  'The BossHoss': 1,
#  'Boston Manor (Band)': 2,
#  'Bottom of the River - Delta Rae (Song)': 4,
#  'Bottom of the River (Music Video)': 2,
#  'Bowling For Soup (Band)': 2,
#  'The Boxer - Simon & Garfunkel (Song)': 3,
#  'Boy Band (TV)': 6,
#  'Boy George (Musician)': 26,
#  'Boy Story (Band)': 34,
#  'BoybandPH (Band)': 3,
#  'Boyfriend (Band)': 90,
#  'BOYFRIENDS (Thailand Band)': 1,
#  'boygenius (Band)': 3,
#  'The Boys Are Back in Town (to kill you) - JerryTerry (Music Video)': 2,
#  'Boys Boys Boys - Lady Gaga (Song)': 1,
#  'Boys for Pele - Tori Amos (Album)': 3,
#  'Boys generally Asian | BgA': 13,
#  'Boys Like Girls (Band)': 1,
#  'The Boys of Summer - Don Henley (Song)': 2,
#  'Boys Republic (Band)': 28,
#  'Boys World (US Band)': 1,
#  'The Boyz (Korea Band)': 3922,
#  'Boyzone (Band)': 6,
#  'The Bramble Briar | In Bruton Town - Anonymous (Song)': 1,
#  'Brand New (Band)': 26,
#  "Brandy (You're a Fine Girl) - Looking Glass (Song)": 13,
#  'Brave - Marillion (Album)': 1,
#  'Brave - Sara Bareilles (Song)': 1,
#  'Brave Girls (Korea Band)': 1,
#  '上线吧！华彩少年 | Bravo Youngsters! (TV)': 2,
#  'Break It Yourself - Andrew Bird (Album)': 2,
#  'BREAKERZ': 13,
#  'Breaking Benjamin (Band)': 105,
#  'Breaking Pangaea (Band)': 1,
#  'Breathe Carolina': 4,
#  'Bree Sharp (Musician)': 1,
#  'Brett Eldredge (Musician)': 1,
#  'Brian London (Musician)': 11,
#  'Brides of Destruction (Band)': 1,
#  'Bright Eyes (Band)': 13,
#  'Бриллиантовые дороги | Brillyantoviye Dorogi - Gleb Samoyloff & The MATRIXX (Song)': 1,
#  'Bring Me The Horizon': 311,
#  'British Singers RPF': 619,
#  'Britney Spears (Musician)': 40,
#  'Britny Fox (Band)': 1,
#  'Broadside (Band)': 1,
#  'The Brobecks': 97,
#  'BROCKHAMPTON (Band)': 54,
#  'Broken Bride - Ludo (Album)': 3,
#  'Broken Machine - Nothing But Thieves (Album)': 1,
#  'Broken Social Scene': 1,
#  'Bronte - Gotye (Music Video)': 7,
#  'Bros (UK Band)': 1,
#  'Brown-Eyed Girls (Band)': 27,
#  'Bruce Springsteen & the E Street Band': 28,
#  'Brun - Garmarna (Song)': 1,
#  'Bruno Mars (Musician)': 18,
#  'BT (Musician)': 4,
#  'BTD (Before the Dawn) - Infinite (Music Video)': 1,
#  'BTOB (Band)': 622,
#  'Bubble Pop Electric - Gwen Stefani ft. Johnny Vulture': 1,
#  'BUCK-TICK': 310,
#  'Budka Suflera (Band)': 1,
#  'Buffalo Springfield (Band)': 6,
#  'bugAboo (Band)': 1,
#  'BugLug': 2,
#  'BUGVEL (Band)': 1,
#  "Build God Then We'll Talk - Panic! at the Disco (Music Video)": 1,
#  "Build That Wall (Zia's Theme) - Darren Korb (Song)": 2,
#  'Bulldok (Band)': 3,
#  'Bullet - Covenant (Song)': 1,
#  'Bullet For My Valentine': 8,
#  'Bump of Chicken (Band)': 4,
#  'Buono! (Band)': 1,
#  'Burn Witch Burn - Ego Likeness (Song)': 1,
#  'bury a friend - Billie Eilish (Music Video)': 3,
#  'Bury My Lovely - October Project (Music Video)': 2,
#  'Burzum (Band)': 23,
#  'Bus Stop - The Hollies (Song)': 1,
#  'Bushes of Love - Bad Lip Reading (Song)': 1,
#  'Bushido (Musician) RPF': 18,
#  'Busker Busker (Band)': 1,
#  'Busted (Band)': 47,
#  'Busters (Band)': 6,
#  'Butch Walker (Musician)': 4,
#  "Butch Walker and the Let's-Go-Out-Tonites": 1,
#  'Butcher Babies (Band)': 1,
#  'BUTOUKAN': 4,
#  'Butterfly - Rajaton (Song)': 1,
#  'Butterfly Syndrome (Band)': 1,
#  'Buzz (Korea Band)': 99,
#  'BVCCI HAYNES': 25,
#  'BVNDIT (Band)': 12,
#  'BXW (Japan Band)': 2,
#  'By and By - Caamp (Song)': 1,
#  'By-Sexual (Band)': 3,
#  'The Byrds (Band)': 17,
#  'C-Clown': 30,
#  'C-Pop': 618,
#  'C-ute': 9,
#  'The Cab (Band)': 84,
#  'Cabinet Man - Lemon Demon (Song)': 7,
#  'Cacophony (Band)': 1,
#  'Cadaveria (Musician)': 2,
#  'Cage the Elephant - Cage the Elephant (Album)': 5,
#  "Cain's Offering": 1,
#  'Cairokee (Band)': 1,
#  'CALABRESE (Band)': 1,
#  'Cali Gari': 2,
#  'California - Mylène Farmer (Music Video)': 1,
#  'Call Me - Blondie (Song)': 1,
#  '披荆斩棘的哥哥 | Call Me By Fire (TV)': 133,
#  'Call Me Maybe - Carly Rae Jepsen (Music Video)': 6,
#  "Call Me When You're Sober - Evanescence (Music Video)": 1,
#  'Call the Ships to Port - Covenant (Song)': 1,
#  'Calling Occupants of Interplanetary Craft - Klaatu (Song)': 1,
#  'Calvin Harris (Musician)': 5,
#  'Camila Cabello (Musician)': 30,
#  "Can't Remember to Forget You - Shakira ft. Rihanna (Music Video)": 1,
#  "Can't Stop Drinking About You - Otto Knows vs. Bebe Rexha (Song)": 1,
#  'Canadian Idol RPF': 26,
#  'Canadian Music RPF': 654,
#  'Canadian Musician RPF (C6D)': 6,
#  'CANARY (Band)': 2,
#  'Cane Hill (Band)': 1,
#  'CANIVAL (Band)': 1,
#  'El Canto del Loco': 1,
#  'Captain Fantastic and the Brown Dirt Cowboy - Elton John (Song)': 1,
#  'Car Seat Headrest (Band)': 4,
#  'Car Wash - Bruce Springsteen (Song)': 2,
#  'Carach Angren (Band)': 12,
#  'Caramella Girls (Virtual Band)': 1,
#  'Carat (Japan Band)': 2,
#  'Caravan Palace (Band)': 4,
#  'Cardiacs (UK Band)': 2,
#  'cardigan - Taylor Swift (Song)': 18,
#  'Career of Evil - Blue Oyster Cult (Song)': 1,
#  'Cargill - King Creosote (Song)': 4,
#  'Carly Rae Jepsen (Musician)': 6,
#  'Carnival Glass - Seanan McGuire (Song)': 1,
#  'The Carnival Is Over - Dead Can Dance (Song)': 2,
#  'The Carnival Is Over - The Seekers (Song)': 3,
#  'Carnival of Rust - Poets of the Fall (Music Video)': 3,
#  'Carolina - Harry Styles (Song)': 7,
#  'The Carpenters (Band)': 2,
#  'Carrie Underwood (Musician)': 1,
#  'The Cars (Band)': 6,
#  'Cartel (Band)': 2,
#  'Cartography - Seanan McGuire (Song)': 1,
#  'Les Casseurs Flowters (Band)': 53,
#  'Cassidy Haley (Musician)': 16,
#  'Cat-Eye Willie Claims His Lover - Dave Carter and Tracy Grammer (Song)': 2,
#  'CatchingYourClouds': 1,
#  'Catellena - Orange Caramel (Music Video)': 1,
#  'Catfish and the Bottlemen (Band)': 322,
#  'Cattle Decapitation (Band)': 1,
#  'Cavetown (Band)': 5,
#  'Celebrity - NSYNC (Album)': 1,
#  'Celestial Garden (Band)': 4,
#  'Celine Dion (Musician)': 3,
#  'Celldweller (Band)': 2,
#  'Celtic Thunder (Band)': 23,
#  'Celtic Woman (Band)': 3,
#  'Centuries - Fall Out Boy (Music Video)': 6,
#  'CeVIO': 39,
#  'The Chaconne - Dessa (Song)': 1,
#  'The Chain - Fleetwood Mac (Song)': 2,
#  'The Chainsmokers (Band)': 8,
#  'Chakuza (Musician)': 3,
#  'Chameleon Circuit (Band)': 1,
#  'champagne problems - Taylor Swift (Song)': 5,
#  'Champagne Supernova - Oasis (Song)': 1,
#  'Champions of Red Wine - The New Pornographers (Song)': 1,
#  'Chandelier - Sia (Song)': 2,
#  'Channel Z - The B-52s (Song)': 1,
#  '潮音战纪 | Chao Yin Zhan Ji (TV)': 7,
#  'Charli XCX (Musician)': 6,
#  'The Charlie Daniels Band (Band)': 1,
#  'Charlie Puth (Musician)': 19,
#  'Charlotte Sometimes (Musician)': 2,
#  'CHARM (Band)': 2,
#  'Chase Atlantic (Band)': 10,
#  'Chase Me - Dreamcatcher (Music Video)': 15,
#  'Chayanne (Musician)': 1,
#  'CHELSEA (Japan Band)': 1,
#  'Chemistry - All Time Low (Song)': 2,
#  'Cher (US Musician) RPF': 4,
#  'Черная река - БИ-2 | Chernaya Reka - BI-2 (Song)': 2,
#  'Черные птицы - Наутилус Помпилиус | Chernye ptitsy - Nautilus Pompilius (Song)': 1,
#  'Cherri Bomb': 2,
#  'Cherry Bullet (Band)': 15,
#  'Cherry Glazerr (Band)': 1,
#  'Cherry Wine - Hozier (Song)': 1,
#  'Cheshires (Band)': 2,
#  'Chick Habit - April March (Song)': 1,
#  'The Chicks (US Band)': 1,
#  'CHILDCARE (UK Band)': 2,
#  'Childe Rowland - Anonymous (Song)': 2,
#  'Childish Gambino (Musician)': 7,
#  'Children of Bodom': 15,
#  'Chipspeech': 18,
#  'Chitown Hipsters': 3,
#  'Chloe x Halle (Band)': 3,
#  '쇼콜라 | Chocolat (Band)': 1,
#  'CHON (Band)': 1,
#  '筷子兄弟 | Chopstick Brothers (Band)': 1,
#  'Черное солнце - БИ-2 | Chornoye Solntse - BI-2 (Music Video)': 3,
#  'Черное солнце - БИ-2 | Chornoye Solntse - BI-2 (Song)': 1,
#  'Chris Brown (Musician) RPF': 7,
#  'Chris de Burgh (Musician)': 29,
#  'Christian Burns (Musician)': 1,
#  'Christina Aguilera (Musician)': 11,
#  'Christmas Eve and Other Stories - Trans-Siberian Orchestra (Album)': 1,
#  'Christmas Wrapping - The Waitresses (Song)': 1,
#  'Chronic Future (Band)': 1,
#  'Chronicle 2nd - Sound Horizon (Album)': 1,
#  'Что Такое Осень - ДДТ | Chto Takoe Osen - DDT (Song)': 2,
#  'Chu - f(x) (Music Video)': 2,
#  'Chungha (Musician)': 64,
#  'Chunk! No Captain Chunk! (Band)': 3,
#  'Church Bells - Carrie Underwood (Song)': 3,
#  'CHVRCHES (Band)': 1,
#  'Чёрная звезда - Кипелов | Chyornaya Zvezda - Kipelov (Song)': 1,
#  'Cigarettes After Sex - Cigarettes After Sex (Album)': 1,
#  'Cignature (Band)': 19,
#  'CIIPHER (Band)': 8,
#  'Cimorelli (Band)': 2,
#  'Cinderella (Band)': 12,
#  'Cinema Bizarre (Band)': 31,
#  'Cirque - Sub Urban (Music Video)': 1,
#  'City Hall - Vienna Teng (Song)': 1,
#  'City Morgue (Band)': 3,
#  'City of Angels - Coleman/Zippel/Gelbar': 1,
#  'Ciuffi Rossi': 1,
#  'The Civil Wars (Band)': 17,
#  'CIX (Band)': 220,
#  'CKY (Band)': 19,
#  'The Clash': 51,
#  'Class of Cardinal Sin - Covey (Album)': 9,
#  'Classical Music RPF': 237,
#  'Clazziquai': 3,
#  'CLC (Band)': 158,
#  'Clean Bandit (Band)': 36,
#  'Cleansing Cream - Brown Eyed Girls (Music Video)': 1,
#  'ClearVeil (Band)': 3,
#  'Cleopatra - The Lumineers (Song)': 1,
#  'Click-B (Band)': 1,
#  'Click#15 (Band)': 3,
#  'Clipping (US Band)': 1,
#  'Close Your House Down - Cordero (Song)': 1,
#  'Closer - Oh My Girl (Music Video)': 3,
#  'Closer - The Chainsmokers ft. Halsey (Music Video)': 1,
#  'Closing Time - Leonard Cohen (Song)': 3,
#  'closure - Taylor Swift (Song)': 1,
#  'Cloudburst at Shingle Street - Thomas Dolby (Song)': 2,
#  'Clutching At Straws - Marillion (Album)': 1,
#  'CNBLUE (Band)': 46,
#  'CNCO (Band)': 26,
#  'Cnema (Band)': 1,
#  'Co-ed School (Band)': 61,
#  'Cobra Starship': 1381,
#  'Coco Avenue (Band)': 1,
#  'Cocoa Otoko': 21,
#  'Coconut Records': 1,
#  'CoCoSoRi (Band)': 4,
#  'Code Monkey - Jonathan Coulton (Song)': 2,
#  'コドモドラゴン | Codomo Dragon': 25,
#  'Cody Simpson (Musician)': 2,
#  'Coheed and Cambria (Band)': 6,
#  'Coin-Operated Boy - The Dresden Dolls (Song)': 2,
#  'Çok Çok - Edis (Music Video)': 1,
#  'Cold (House by the Sea) - Mean Mary (Song)': 1,
#  'Cold Blows the Wind - Ween (Song)': 1,
#  'Cold Wind - Kitty and the Can Openers (Song)': 1,
#  'Coldplay (Band)': 90,
#  'coldrain (Japan Band)': 22,
#  'The Collective (Band)': 1,
#  'Collective Soul (Band)': 2,
#  'Colleen - Joanna Newsom (Song)': 1,
#  'Collide with the Sky - Pierce the Veil (Album)': 3,
#  'Color (Japan Band)': 1,
#  'The Color Fred (Band)': 1,
#  'Colors - Halsey (Music Video)': 1,
#  'Colors - Halsey (Song)': 5,
#  'Combichrist': 2,
#  'Come And Find Me - Josh Ritter (Song)': 1,
#  'Come Back Home - 2NE1 (Music Video)': 5,
#  'Come Little Children - Sarah Jessica Parker (Song)': 1,
#  'Comfortably Numb - Pink Floyd (Song)': 2,
#  '明日之子 | The Coming One (TV)': 401,
#  'Common People - Pulp (Song)': 1,
#  'COMMUNICATIONS - GHOST | GHOST and Pals (Songs)': 22,
#  'A Complete History of the Soviet Union as Told by a Humble Worker Arranged to the Melody of Tetris': 5,
#  'The Con - Tegan and Sara (Album)': 3,
#  'coney island - Taylor Swift (Song)': 1,
#  '告白実行委員会 | Confession Executive Committee': 1538,
#  'Confide (Band)': 1,
#  'Confident - Demi Lovato (Music Video)': 12,
#  'Control - Halsey (Song)': 2,
#  'Conventional Weapons - My Chemical Romance (Album)': 6,
#  'Convoy (Song)': 2,
#  'Cool Patrol - Ninja Sex Party (Song)': 18,
#  'Copacabana (Song)': 1,
#  'Coppelius (Band)': 1,
#  'Corey Harper (Musician)': 1,
#  'Cornbugs (Band)': 4,
#  'Corvus Corax (Band)': 1,
#  '우주소녀 | Cosmic Girls | WJSN': 565,
#  'Count on Me - Brockhampton (Music Video)': 2,
#  'COUNTERFEIT (Band)': 30,
#  'Counting Crows (Band)': 1,
#  'Country Christmas - Loretta Lynn (Song)': 1,
#  'Country Girls (Japan Band)': 10,
#  'Country Kko Kko (Band)': 2,
#  'Country Music RPF': 103,
#  "Couple d'Ange (Japan Band)": 3,
#  'Courtyard Lullaby - Loreena McKennitt (Song)': 2,
#  'Coverdale–Page (Band)': 1,
#  'Covette (Band)': 1,
#  'The Cowboy and the Lady - John Denver (Song)': 1,
#  'cowboy like me - Taylor Swift (Song)': 2,
#  'Coyote Milk Store (Band)': 1,
#  'Cradle of Filth': 2,
#  'The Crane Wife 1-3 - The Decemberists (Songs)': 8,
#  'The Crane Wives (Band)': 4,
#  'CRASHDÏET (Band)': 2,
#  'Cravity (Band)': 787,
#  'Crayon Pop (Band)': 5,
#  'Crazy - Aerosmith (Music Video)': 6,
#  'CrazyEightyEight (Band)': 1,
#  'CRAZYNO (Musician)': 1,
#  'Cream (Band)': 2,
#  'Creature Creature (Band)': 5,
#  'Creature Feature (Band)': 6,
#  'The Creatures (UK Band)': 2,
#  'Creed (Band)': 2,
#  'Creedence Clearwater Revival (Band)': 1,
#  'Creeper (UK Band)': 8,
#  'Creepy Doll - Jonathan Coulton (Song)': 4,
#  'Crestillion (Band)': 1,
#  'Crosby Stills Nash & Young (Band)': 9,
#  'CROSS GENE': 67,
#  'Crosses (Band)': 2,
#  'Crossfaith (Band)': 1,
#  'Crossfire - Brandon Flowers (Music Video)': 4,
#  'Crown The Empire': 18,
#  'Crucifixion (Japan Band)': 1,
#  'The Crüxshadows': 6,
#  'Cry Baby - Melanie Martinez (Album)': 21,
#  'Cry Cry - T-ara (Music Video)': 1,
#  'Cry For Judas (Music Video) - The Mountain Goats': 2,
#  'Crystal Castles (Band)': 3,
#  '天上智喜 The Grace | CSJH The Grace': 16,
#  'Cuenta Pendiente - Paty Cantú ft. Alejandro Sanz (Music Video)': 1,
#  'Culling of the Fold - The Decemberists (Song)': 1,
#  'The Cult (Band)': 6,
#  'Culture Club (Band)': 24,
#  'Cupcakke (Musician) RPF': 4,
#  'The Cure (Band)': 64,
#  'The Curse - Josh Ritter (Song)': 2,
#  'The Cursed Path - Lionel Yu (Song)': 1,
#  'Cursed Sails (Band)': 1,
#  'Cutting Crew (Band)': 2,
#  ...}

# %%
fandoms_sorted = dict(sorted(fandoms.items(), key=lambda item: item[1], reverse=True)) #sorted

# %%
fandoms_sorted.pop('K-pop', None)
fandoms_sorted.pop('Music RPF', None)
fandoms_sorted.pop('Bandom', None)
fandoms_sorted.pop('Rock Music RPF', None)
fandoms_sorted.pop('Jpop', None)
fandoms_sorted.pop('Jrock', None)
fandoms_sorted.pop('Pop Music RPF', None)
fandoms_sorted.pop('Popslash', None)
fandoms_sorted.pop('Hip Hop RPF', None)
for key in fandoms:
    if '(Song)' in key or '(TV)' in key or '(Album)' in key or '(Albums)' in key:
        fandoms_sorted.pop(key, None)

# %%
fandoms_sorted
# Out:
# {'방탄소년단 | Bangtan Boys | BTS': 169884,
#  'One Direction (Band)': 61598,
#  'NCT (Band)': 51666,
#  'EXO (Band)': 44190,
#  'SEVENTEEN (Band)': 27594,
#  'Stray Kids (Band)': 26409,
#  "Johnny's Entertainment": 19902,
#  'My Chemical Romance': 17376,
#  'GOT7': 14328,
#  'Monsta X (Band)': 11556,
#  'ATEEZ (Band)': 11083,
#  'Fall Out Boy': 10604,
#  '5 Seconds of Summer (Band)': 10043,
#  'Twenty One Pilots': 8695,
#  'TOMORROW X TOGETHER | TXT (Korea Band)': 8498,
#  'Super Junior': 7958,
#  'Panic! at the Disco': 7715,
#  'Queen (Band)': 7705,
#  'TWICE (Band)': 7524,
#  'Arashi (Band)': 6946,
#  'YG Entertainment | YG Family': 6892,
#  'Wanna One (Band)': 6097,
#  '1960s Music Scene RPF': 6078,
#  'SHINee': 6024,
#  'VIXX': 5798,
#  'The Beatles (Band)': 5118,
#  'DBSK | Tohoshinki | TVfXQ | TVXQ': 4691,
#  'Adam Lambert (Musician)': 4264,
#  'LOONA (Korea Band)': 3942,
#  'The Boyz (Korea Band)': 3922,
#  'Red Velvet (K-pop Band)': 3731,
#  'NINE PERCENT (Band)': 3689,
#  'Hey! Say! JUMP (Band)': 3530,
#  'Day6 (Band)': 3414,
#  'Vocaloid': 3255,
#  'ENHYPEN (Band)': 3227,
#  'iKON (Korea Band)': 2786,
#  'BLACKPINK (Band)': 2712,
#  'X1 (Korea Band)': 2628,
#  'Big Bang (Band)': 2534,
#  "NU'EST": 2452,
#  'Dreamcatcher (Korea Band)': 2442,
#  '创造101 | Produce 101 (China TV)': 2404,
#  'INFINITE (Band)': 2339,
#  'ONEUS (Band)': 2266,
#  'Ghost - Ambiguous Fandom': 2249,
#  'B.A.P': 2232,
#  'ASTRO (Band)': 2215,
#  'Ghost (Sweden Band)': 2208,
#  'Gorillaz': 2207,
#  'the GazettE (Band)': 2131,
#  'Kanjani8 (Band)': 2033,
#  'Mamamoo': 1940,
#  'The Mechanisms (Band)': 1934,
#  'KAT-TUN (Band)': 1877,
#  'MIRROR (Hong Kong Band)': 1797,
#  'Pentagon (Korea Band)': 1774,
#  'TFBOYS (Band)': 1762,
#  'All Time Low (Band)': 1758,
#  'SuperM (Korea Band)': 1713,
#  'R1SE (Band)': 1644,
#  'Winner (Band)': 1554,
#  '告白実行委員会 | Confession Executive Committee': 1538,
#  'KinKi Kids (Band)': 1457,
#  'JJ Project': 1456,
#  'Backstreet Boys': 1442,
#  'Rammstein': 1383,
#  'Cobra Starship': 1381,
#  'VICTON (Band)': 1378,
#  'NEWS (Japan Band)': 1368,
#  'ONER (Band)': 1365,
#  'NSYNC': 1354,
#  'SF9 (Band)': 1337,
#  'Tommy Ratliff (Musician)': 1282,
#  'A.C.E (Beat Interactive Band)': 1280,
#  'JYJ (Band)': 1255,
#  'Kagerou Project': 1214,
#  'Tokio Hotel': 1209,
#  'TREASURE (Korea Band)': 1163,
#  'Dir en grey': 1160,
#  'JO1 (Japan Band)': 1097,
#  'Taylor Swift (Musician)': 1086,
#  'Mystery Skulls Animated': 1077,
#  'Eurovision Song Contest RPF': 1062,
#  'Block B (Band)': 1059,
#  "소녀시대 | Girls' Generation | SNSD": 1059,
#  "Guns N' Roses": 1058,
#  'Disney RPF': 1034,
#  'IZONE (Band)': 1028,
#  'UP10TION': 1025,
#  'ITZY (Band)': 1018,
#  'Muse (Band)': 992,
#  'The Academy Is...': 985,
#  '(여자)아이들 | (G)I-DLE': 962,
#  'Hanson (Band)': 937,
#  'Oasis (Band)': 922,
#  'SixTONES (Band)': 911,
#  'Hadestown - Mitchell': 909,
#  'Steam Powered Giraffe': 874,
#  'Electronic Dance Music RPF': 871,
#  'Kris Allen (Musician)': 860,
#  'Golden Child (Korea Band)': 834,
#  'Mötley Crüe': 834,
#  'SB19 (Band)': 829,
#  'Waterparks (Band)': 827,
#  'Fifth Harmony (Band)': 801,
#  'Cravity (Band)': 787,
#  'Festival di Sanremo RPF': 760,
#  'Måneskin (Band)': 753,
#  'Led Zeppelin': 747,
#  '30 Seconds to Mars': 746,
#  'Last Shadow Puppets': 733,
#  'Arctic Monkeys': 717,
#  'Pentatonix': 701,
#  'f(x)': 700,
#  'AKB48 & Related Fandoms': 698,
#  'Pierce the Veil': 678,
#  'Little Mix (Band)': 663,
#  'Green Day': 658,
#  'Finnish Music RPF': 657,
#  'Canadian Music RPF': 656,
#  'Slipknot (Band)': 640,
#  'ONF (Band)': 639,
#  'AB6IX (Band)': 634,
#  'BTOB (Band)': 622,
#  'British Singers RPF': 619,
#  'C-Pop': 618,
#  'Black Veil Brides': 614,
#  'UNIQ (Band)': 613,
#  'Metallica': 608,
#  'Kis-My-Ft2 (Band)': 604,
#  'ONEWE (Band)': 600,
#  'UNINE (Band)': 596,
#  'EXILE (Japan Band)': 588,
#  'Jonas Brothers': 567,
#  '우주소녀 | Cosmic Girls | WJSN': 565,
#  'Take That (Band)': 557,
#  'Ylvis RPF': 557,
#  'Indie Music RPF': 555,
#  'Sleeping With Sirens': 552,
#  'Linkin Park': 542,
#  'SNH48': 522,
#  "Johnny's Jr.": 516,
#  'Duran Duran': 515,
#  'Sexy Zone (Band)': 515,
#  'Blind Channel (Band)': 512,
#  'The Used': 505,
#  'Superfruit': 502,
#  'Bastille (Band)': 498,
#  'Young Veins': 496,
#  'Produce 101 (Japan TV)': 480,
#  'A9 | Alice Nine (Band)': 471,
#  'Bon Jovi (Band)': 470,
#  '歌い手 | Utaite': 459,
#  'Glam Rock RPF': 451,
#  'X Factor RPF': 450,
#  'PRISTIN (Band)': 448,
#  'Tiny Meat Gang (Band)': 448,
#  'Shawn Mendes (Musician)': 447,
#  'Marilyn Manson (Band)': 435,
#  'ONE OK ROCK': 432,
#  'David Bowie (Musician)': 431,
#  'Daft Punk': 417,
#  'Kane (Band)': 417,
#  'Aespa (Band)': 408,
#  '여자친구 | GFriend (Band)': 406,
#  'INTO1 (Band)': 399,
#  'Paramore': 398,
#  'Avenged Sevenfold': 397,
#  'Blur (Band)': 394,
#  '时代少年团 | Teens in Times (Band)': 389,
#  'The Monkees (Band)': 386,
#  'Evillious Chronicles': 377,
#  'Super Junior-M': 369,
#  'Machine Gun Kelly (Musician)': 368,
#  'TWRP | Tupper Ware Remix Party (Band)': 364,
#  'The Smiths': 362,
#  'Westlife': 357,
#  'Mindless Self Indulgence (Band)': 355,
#  '2PM (Band)': 353,
#  'KISS (US Band)': 352,
#  'Hollywood Undead (Band)': 350,
#  'I-LAND (Korea TV)': 343,
#  'SMAP (Band)': 342,
#  'X JAPAN': 340,
#  'JBJ (Band)': 335,
#  'The 1975 (Band)': 332,
#  'Punk Rock RPF': 332,
#  'Topp Dogg | Xeno-T (Band)': 331,
#  'AFI (Band)': 323,
#  'Catfish and the Bottlemen (Band)': 322,
#  'U2 (Band)': 319,
#  'Bring Me The Horizon': 311,
#  'BUCK-TICK': 310,
#  'The Rolling Stones': 306,
#  'Blake Shelton (Musician)': 305,
#  'Greta Van Fleet (Band)': 302,
#  '乐华七子NEXT | NEX7': 302,
#  'Ed Sheeran (Musician)': 296,
#  'J Soul Brothers (Band)': 294,
#  'Big Time Rush (Band)': 284,
#  'frnkiero andthe cellabration': 284,
#  'Palaye Royale (Band)': 277,
#  'Snow Man (Japan Band)': 277,
#  'You Me At Six': 272,
#  "I Don't Know How But They Found Me (Band)": 271,
#  'VERIVERY (Band)': 270,
#  '크나큰 | KNK (Band)': 267,
#  'Blink-182': 266,
#  'Gerard Way and the Hormones': 266,
#  'Motionless in White (Band)': 266,
#  'Yungblud (Musician)': 264,
#  'UTAU': 261,
#  'The Who (Band)': 260,
#  'AKB48': 257,
#  'N.Flying (Band)': 255,
#  'SM Rookies': 253,
#  'SECHSKIES (Band)': 252,
#  'Nirvana (Band)': 248,
#  'Shinhwa (Band)': 244,
#  'Halsey (Musician)': 242,
#  'McFly (Band)': 240,
#  'Classical Music RPF': 237,
#  'Gackt (Musician) RPF': 237,
#  'Poets of the Fall': 235,
#  'Eminem (Musician)': 234,
#  'Justin Bieber (Musician)': 231,
#  'CIX (Band)': 220,
#  '2NE1': 219,
#  'Highlight | Beast (Band)': 219,
#  'Generations from Exile Tribe (Band)': 216,
#  'Pink Floyd': 214,
#  'The Libertines': 212,
#  'New Kids On The Block': 211,
#  'GTOP (Band)': 210,
#  'Union J (Band)': 210,
#  'MXM (Band)': 208,
#  'OnlyOneOf (Band)': 207,
#  'Hello! Project': 206,
#  'HOTSHOT (Band)': 206,
#  'Malice Mizer': 206,
#  'Fleetwood Mac (Band)': 204,
#  "L'Arc~en~Ciel": 204,
#  'Gym Class Heroes': 202,
#  'The Rampage from Exile Tribe (Band)': 199,
#  'Oh My Girl (Band)': 197,
#  'Depeche Mode': 195,
#  'Mayhem (Band)': 193,
#  'Mr. King vs Mr. Prince (Band)': 192,
#  'Michael Jackson (Musician)': 186,
#  'Z.Tao (Musician)': 186,
#  'Andrew Hozier-Byrne (Musician)': 184,
#  'K.A.R.D (Band)': 176,
#  'Nightwish': 176,
#  'THE9 (Band)': 176,
#  'We Go Up - NCT Dream (Music Video)': 172,
#  'Adam Levine (Musician)': 171,
#  'Keyakizaka46 (Band)': 170,
#  'Frank Iero and the Patience': 169,
#  'MEJIBRAY': 168,
#  'B1A4': 165,
#  'Florence + the Machine': 165,
#  'GacktJOB': 165,
#  'A Very Potter Musical Series - Team StarKid': 163,
#  'Megadeth': 161,
#  'Sabaton (Band)': 160,
#  'WEi (Korea Band)': 159,
#  'CLC (Band)': 158,
#  'U-KISS': 158,
#  'The Travelling Wilburys (Band)': 156,
#  'EXID (Band)': 153,
#  'I.O.I (Band)': 150,
#  '火箭少女 | Rocket Girls (Band)': 149,
#  'Hurts (UK Band)': 148,
#  'Lovelyz': 148,
#  'Nine Inch Nails (Band)': 148,
#  'Afterhours (Band)': 147,
#  'Def Leppard': 147,
#  'Best Song Ever - One Direction (Music Video)': 146,
#  'LeATHERMØUTH': 144,
#  '新裤子 | New Pants (Band)': 143,
#  'SCREW (Band)': 143,
#  'D (Band)': 141,
#  'Gloryhammer (Band)': 137,
#  'fromis_9 (Band)': 136,
#  'MIKA (Musician) RPF': 135,
#  'Versailles (Band)': 135,
#  'Morning Musume.': 133,
#  '台风少年团 | Typhoon Teens (Band)': 133,
#  'English and Scottish Popular Ballads - Francis James Child': 131,
#  'Melanie Martinez (Musician)': 131,
#  'HIM (Band)': 130,
#  'Placebo (UK Band)': 130,
#  'UNB (Band)': 129,
#  'V6 (Band)': 128,
#  'Pearl Jam': 127,
#  'The Rose (Band)': 126,
#  'TOKIO (Japan Band)': 126,
#  'Gugudan (Band)': 125,
#  '易安音乐社 | Yi An Musical (Band)': 123,
#  'Midwest Kings': 122,
#  'Miss A': 122,
#  'Show Me the Money (Korea TV)': 122,
#  'X Factor (UK) RPF': 122,
#  'The Vamps (UK Band)': 121,
#  'Demi Lovato (Musician)': 120,
#  'A Pink (Band)': 118,
#  'Bob Dylan (Musician)': 118,
#  'Falling in Reverse': 118,
#  'Kagrra': 117,
#  'Marianas Trench (Band)': 117,
#  'LUNA SEA': 116,
#  'MBLAQ': 116,
#  'Set It Off (Band)': 116,
#  'Morrissey (Musician) RPF': 114,
#  'IU (Musician)': 112,
#  'Radiohead (Band)': 112,
#  'Alice in Chains': 111,
#  '时之歌 | Song of Time Project': 111,
#  'Teen Top (Band)': 109,
#  'The Kinks (Band)': 107,
#  'Nogizaka46 (Band)': 107,
#  "Why Don't We (Band)": 107,
#  "Initial'L (Band)": 106,
#  'Breaking Benjamin (Band)': 105,
#  'Repugnant (Band)': 105,
#  'H.O.T. (Band)': 104,
#  'Jay Park (Musician)': 104,
#  'Murderdolls (Band)': 104,
#  'Of Mice & Men (Band)': 104,
#  'TO1 | TOgether as 1 (Band)': 104,
#  'Country Music RPF': 103,
#  'Empires (Band)': 103,
#  'STARSET (Band)': 103,
#  'Tegan and Sara (Band)': 102,
#  'Triple H (Korea Band)': 102,
#  'X 玖少年团 | X-NINE (Band)': 102,
#  'Urban Strangers (Band)': 101,
#  "Johnny's WEST": 100,
#  'Panik (Band)': 100,
#  'Buzz (Korea Band)': 99,
#  '終焉ノ栞プロジェクト | Shuuen no Shiori Project': 99,
#  'The Ramones': 98,
#  'The Brobecks': 97,
#  'Soundgarden (Band)': 96,
#  'David Cook (Musician)': 94,
#  '华晨宇 | Hua Chenyu (Musician)': 94,
#  'Apocalyptica (Band)': 93,
#  'Frank Iero and the Future Violents (Band)': 93,
#  'GNZ48 (Band)': 93,
#  'Weki Meki (Band)': 93,
#  'Hyde (Musician) RPF': 92,
#  'P1Harmony (Band)': 92,
#  'Mayday (Taiwan Band)': 91,
#  'Boyfriend (Band)': 90,
#  'Coldplay (Band)': 90,
#  'History (Band)': 90,
#  'Royz': 89,
#  'Sound Horizon (Band) RPF': 88,
#  'Lemon Demon (Musician)': 87,
#  'The Wanted (Band)': 86,
#  'Intersection (Band)': 85,
#  'The Cab (Band)': 84,
#  'Dr. Carmilla (Musician)': 84,
#  'Hush Sound': 84,
#  '己龍 | Kiryuu': 84,
#  'Within Temptation (Band)': 84,
#  'All-American Rejects': 83,
#  'AOA | Ace of Angels': 83,
#  'As It Is (Band)': 83,
#  'Hatari (Band)': 83,
#  'MCND (Band)': 83,
#  'The Strokes': 83,
#  '五堅情 | W0LF(S) (Band)': 83,
#  '大波浪 | THE BIG WAVE (Band)': 79,
#  'The Like (Band)': 79,
#  'Midtown (Band)': 78,
#  '燃烧吧少年! | X-Fire RPF': 78,
#  'Anthrax (US Band)': 77,
#  'Lady Gaga (Musician)': 77,
#  'Simon & Garfunkel': 77,
#  'SKE48': 77,
#  'The Young Blood Chronicles - Fall Out Boy (Music Video)': 77,
#  'Foo Fighters': 76,
#  'Genghis Khan - Miike Snow (Music Video)': 76,
#  'Kasabian': 76,
#  'Lana Del Rey (Musician)': 76,
#  'SS501': 76,
#  '4minute (Band)': 75,
#  'BEJ48 (Band)': 75,
#  'Pencey Prep': 75,
#  'Tackey & Tsubasa (Band)': 75,
#  'MUCC': 74,
#  'SID (Japan Band)': 73,
#  'Ariana Grande (Musician)': 72,
#  'EVERGLOW (Band)': 72,
#  'SBFIVE (Band)': 72,
#  'Nightmare (Band)': 71,
#  'Good Charlotte': 70,
#  'Tam Lin (Traditional Ballad)': 70,
#  '15& (Band)': 69,
#  'Miyavi (Musician)': 69,
#  'Selena Gomez (Musician)': 69,
#  'Alkaline Trio (Band)': 68,
#  'The Move (Band)': 68,
#  'Spice Girls': 68,
#  'CROSS GENE': 67,
#  'H&D (Korea Band)': 67,
#  "America's Suitehearts - Fall Out Boy (Music Video)": 66,
#  'VAV (Band)': 66,
#  'Bad Blood - Taylor Swift (Music Video)': 65,
#  'DEAN (Korean Musician)': 65,
#  'Flight of the Conchords - All Media Types': 65,
#  'MILGRAM (Music Videos)': 65,
#  'Powerwolf (Band)': 65,
#  'Chungha (Musician)': 64,
#  'The Cure (Band)': 64,
#  'FANXY CHILD (Band)': 64,
#  'Love-tune | 7ORDER (Band)': 64,
#  'Skid Row (US Band)': 64,
#  'DIAURA': 63,
#  'DRIPPIN (Korea Band)': 63,
#  'Elton John (Musician)': 63,
#  'The Network (Band)': 63,
#  'Hello Future - NCT Dream (Music Video)': 62,
#  'KARA (Band)': 62,
#  'MY FIRST STORY (Band)': 62,
#  'Rush (Band)': 62,
#  'ZE:A (Band)': 62,
#  'Агата Кристи | Agatha Christie (Band)': 61,
#  'Co-ed School (Band)': 61,
#  'Daenamhyup | DNH': 60,
#  'Death Spells (Band)': 60,
#  'Hinatazaka46 (Band)': 60,
#  'McBusted (Band)': 60,
#  'PVRIS (Band)': 60,
#  'Skrillex (Musician)': 60,
#  'X Factor (Italy) RPF': 60,
#  'After School (Band)': 58,
#  'Jupiter (Band)': 58,
#  'Speed (Korea Band)': 58,
#  'VAMPS (Japan Band)': 58,
#  'A.B.C.-Z': 57,
#  'Iron Maiden (Band)': 57,
#  'lynch. (Band)': 57,
#  'Momoland (Band)': 57,
#  'Poison (US Band)': 57,
#  'R5 (Band)': 57,
#  'Three Days Grace (Band)': 57,
#  '걸어 | All in - Monsta X (Music Video)': 56,
#  'Magna Carta Cartel (Band)': 56,
#  'SpeXial (Band)': 56,
#  'Starlight Brigade - TWRP ft. Dan Avidan (Music Video)': 56,
#  'Years & Years (Band)': 56,
#  'Asking Alexandria (Band)': 55,
#  'The Killers (Band)': 55,
#  'SISTAR': 55,
#  'BROCKHAMPTON (Band)': 54,
#  'IMFACT (Band)': 54,
#  'Kep1er (Band)': 54,
#  'Sakurazaka46 (Band)': 54,
#  'Les Casseurs Flowters (Band)': 53,
#  "D'espairsRay": 53,
#  'Eisbrecher': 53,
#  'Electric Light Orchestra': 53,
#  'Escape the Fate (Band)': 53,
#  'KoRn (Band)': 53,
#  'Simple Plan (Band)': 53,
#  'Weezer (Band)': 53,
#  'БИ-2 | BI-2 (Band)': 52,
#  'Secret (Korea Band)': 52,
#  'Sukekiyo (Band)': 52,
#  'Sunmi (Korea Musician)': 52,
#  '五条人 | Wu Tiao Ren (Band)': 52,
#  'Arcadia (UK Band)': 51,
#  'The Clash': 51,
#  'Rudolph the Red-Nosed Reindeer - All Media Types': 51,
#  'Die Ärzte': 50,
#  'Stone Sour (Band)': 50,
#  'GHOST | GHOST and Pals (Musician)': 49,
#  'T-Ara': 49,
#  'BEYOOOOONDS (Band)': 48,
#  'Electric Century': 48,
#  'Isaac Carpenter (Musician)': 48,
#  'Kraftwerk (Band)': 48,
#  'Taking Back Sunday': 48,
#  'VOICEROID': 48,
#  '1The9 (Band)': 47,
#  'Ayabie (Band)': 47,
#  'BAE173 (Band)': 47,
#  'Busted (Band)': 47,
#  'FFC-Acrush (Band)': 47,
#  'Genesis (Band)': 47,
#  'Pete Wentz and His Humans': 47,
#  'RoadTrip (Band)': 47,
#  'CNBLUE (Band)': 46,
#  'Everybody Else (Band)': 46,
#  'F. T. Island': 46,
#  'MYTEEN (Band)': 46,
#  'Pet Shop Boys': 46,
#  'Tim Sköld (Musician)': 46,
#  'B.I.G | Boys in Groove': 45,
#  'Billie Eilish (Musician)': 45,
#  'Deadmau5 (Musician)': 45,
#  'LM.C (Japan Band)': 45,
#  'Sadie (Band)': 45,
#  'Wonder Girls (Band)': 45,
#  "Girl's Day (Band)": 44,
#  "I'm in Love with an E-Girl Series - Wilbur Soot (Song Cycle)": 44,
#  'Manic Street Preachers': 44,
#  'Avatar (Sweden Band)': 43,
#  'DIA (Band)': 43,
#  'Dramarama - Monsta X (Music Video)': 43,
#  'IXFORM (Band)': 43,
#  'The Maccabees (Band)': 43,
#  'Marina & the Diamonds': 43,
#  'Nocturnal Bloodlust': 43,
#  'Shinedown (Band)': 43,
#  'SuG (Band)': 43,
#  'Synthesizer V': 43,
#  'D-OUT (Band)': 42,
#  'Fuck City (Band)': 42,
#  'Glass Animals (Band)': 42,
#  'Sex Pistols (Band)': 42,
#  'Slash (Musician)': 42,
#  'Lord of the Lost (Band)': 41,
#  'Siouxsie and the Banshees (Band)': 41,
#  'Stereo Kicks (Band)': 41,
#  'Zendaya (Musician)': 41,
#  '7 MEN 侍 | 7 MEN Samurai (Band)': 40,
#  'Black Cards (Band)': 40,
#  'Britney Spears (Musician)': 40,
#  'Epic Rap Battles of History (Web Series)': 40,
#  'Eternally - TOMORROW X TOGETHER | TXT (Music Video)': 40,
#  'Girls Like Girls - Hayley Kiyoko (Music Video)': 40,
#  'Kanye West (Musician)': 40,
#  'Nine Muses': 40,
#  'Oxxxymiron (Musician) RPF': 40,
#  'Phantom Planet (Band)': 40,
#  '蘇打綠 | Sodagreen (Band)': 40,
#  'Tom Petty (Musician)': 40,
#  'Alice Cooper (Musician) RPF': 39,
#  'BoA (Musician)': 39,
#  'CeVIO': 39,
#  'Folk Songs': 39,
#  'HINAPIA (Band)': 39,
#  'Just Music Entertainment': 39,
#  'Moi Dix Mois': 39,
#  'The Protomen': 39,
#  'YELLOW FRIED CHICKENz': 39,
#  'Fahrenheit (Taiwan Band)': 38,
#  'Newkidd (Band)': 38,
#  'Nick Cave and the Bad Seeds': 38,
#  'Red Hot Chili Peppers (Band)': 38,
#  'Smile (UK Band 1968)': 38,
#  'System of a Down (Band)': 38,
#  'Der Zibet (Band)': 37,
#  'Franz Ferdinand (Band)': 37,
#  'Imagine Dragons (Band)': 37,
#  'Metropolis Suites - Janelle Monáe': 37,
#  'The Police (Band)': 37,
#  'Weeekly (Korea Band)': 37,
#  'Zemfira (Musician) RPF': 37,
#  '24K (Band)': 36,
#  'Clean Bandit (Band)': 36,
#  'Delain (Band)': 36,
#  '面孔 | The Face (China Band)': 36,
#  'ゴールデンボンバー | Golden Bomber (Band)': 36,
#  'MYNAME (Band)': 36,
#  'Plastic Tree': 36,
#  'Purple Kiss (Band)': 36,
#  'AAA (Band)': 35,
#  'Avantasia (Band)': 35,
#  'Beyoncé Knowles (Musician)': 35,
#  'BORN (Band)': 35,
#  'Глеб Самойлоff & The Matrixx | Gleb Samoyloff & The Matrixx (Band)': 35,
#  'IAMX (Band)': 35,
#  'Interpol (Band)': 35,
#  'The Mountain Goats (Band)': 35,
#  "Noel Gallagher's High Flying Birds (Band)": 35,
#  'Without You - NCT U (Music Video)': 35,
#  'Boy Story (Band)': 34,
#  'The Horrors (Band)': 34,
#  'The Power Station (Band)': 34,
#  '星动亚洲 | Super Idol': 34,
#  'ABBA (Band)': 33,
#  'Gotcharocka': 33,
#  'JUST B (Band)': 33,
#  'King Gnu (Band)': 33,
#  'Love Me Right - EXO (Music Video)': 33,
#  'Penicillin (Band)': 33,
#  'Power - EXO (Music Video)': 33,
#  'Rainbow (Band)': 33,
#  'South Club (Band)': 33,
#  'Type O Negative (Band)': 33,
#  'Il Volo': 33,
#  '1TEAM (Band)': 32,
#  'Like OOH-AHH - Twice (Music Video)': 32,
#  'Lou Reed (Musician)': 32,
#  'LUCY (Korea Band)': 32,
#  'Nicki Minaj (Musician)': 32,
#  'NMB48': 32,
#  'ViViD (Band)': 32,
#  'w-inds. (Band)': 32,
#  'We Are The In Crowd (Band)': 32,
#  'Wolfsheim (Band)': 32,
#  'YHNEXT (Band)': 32,
#  'Axl Rose (Musician)': 31,
#  'Cinema Bizarre (Band)': 31,
#  'Emigrate (Band)': 31,
#  'Gojira (Band)': 31,
#  'HKT48': 31,
#  'Kra (Band)': 31,
#  'The Rock-afire Explosion (Band)': 31,
#  'YDPP (Band)': 31,
#  'Ансамбль Александрова | Alexandrov Ensemble | Red Army Choir': 30,
#  'Blind Melon': 30,
#  'C-Clown': 30,
#  'Camila Cabello (Musician)': 30,
#  'COUNTERFEIT (Band)': 30,
#  'Dance Gavin Dance (Band)': 30,
#  "E'LAST (Band)": 30,
#  'Einstürzende Neubauten': 30,
#  'Jonathan Coulton Songs': 30,
#  'Les Twins': 30,
#  'Angelo (Band)': 29,
#  'Chris de Burgh (Musician)': 29,
#  'Fearless Vampire Killers (Band)': 29,
#  'fun. (Band)': 29,
#  'The Garden of Eden (UK Band)': 29,
#  'HiHi Jets (Band)': 29,
#  'Blue Neighbourhood | Wild - Troye Sivan (Music Videos)': 28,
#  'Boys Republic (Band)': 28,
#  'Bruce Springsteen & the E Street Band': 28,
#  'Failure (Band)': 28,
#  'Feeling B': 28,
#  'German Pop Music RPF': 28,
#  'Kamijo (Musician) RPF': 28,
#  'Reggie and the Full Effect': 28,
#  'School Rapper (Korea TV)': 28,
#  'Tegomass (Band)': 28,
#  'They Might Be Giants': 28,
#  'Yamashita Tomohisa (Musician)': 28,
#  'Brown-Eyed Girls (Band)': 27,
#  'Dadaroma (Band)': 27,
#  'Doberman Infinity (Band)': 27,
#  'Fest Vainqueur': 27,
#  'G-Eazy (Musician) RPF': 27,
#  '華Doll | HanaDoll (Music Videos)': 27,
#  'Hanoi Rocks': 27,
#  'Hard Rock RPF': 27,
#  'Maroon 5': 27,
#  'Nathan Sykes (Musician)': 27,
#  'ORBIT (Japan Band)': 27,
#  'Suede (Band)': 27,
#  'T. Rex (Band)': 27,
#  'Team B (Band)': 27,
#  'Thursday (US Band)': 27,
#  'W.A.S.P. (Band)': 27,
#  '2Cellos': 26,
#  'Angels & Airwaves': 26,
#  'Ария | Aria (Russia Band)': 26,
#  'Boy George (Musician)': 26,
#  'Brand New (Band)': 26,
#  'Canadian Idol RPF': 26,
#  'CNCO (Band)': 26,
#  'DKB (Korea Band)': 26,
#  'IM5 (Band)': 26,
#  'Limp Bizkit (Band)': 26,
#  'Lindsey Stirling (Musician)': 26,
#  'The Maine (Band)': 26,
#  'maNga (Band)': 26,
#  'Melodifestivalen RPF': 26,
#  'MNL48': 26,
#  'Owl City (Band)': 26,
#  'R.E.M. (Band)': 26,
#  'S.K.I.N. (Japan Band)': 26,
#  'Sunrise Avenue (Band)': 26,
#  'VV:D (Band)': 26,
#  'Yes (Band)': 26,
#  'BABYMETAL': 25,
#  '硬糖少女303 | BonBon Girls 303 (Band)': 25,
#  'BVCCI HAYNES': 25,
#  'コドモドラゴン | Codomo Dragon': 25,
#  'The Doors (Band)': 25,
#  'Drab Majesty (Band)': 25,
#  'Ice Nine Kills (Band)': 25,
#  'New Politics (Band)': 25,
#  'Queens of the Stone Age': 25,
#  "Razia's Shadow": 25,
#  'STAYC (Band)': 25,
#  'TT - Twice (Music Video)': 25,
#  'The Verve': 25,
#  'The Band (Band 1968)': 24,
#  'Culture Club (Band)': 24,
#  'Epik High': 24,
#  'exist†trace': 24,
#  'Girls Aloud': 24,
#  'Kaya (Musician)': 24,
#  'Tally Hall (Band)': 24,
#  'Tears for Fears (Band)': 24,
#  '1PUNCH (Band)': 23,
#  'AC/DC (Band)': 23,
#  'Akdong Musician': 23,
#  'BIGFLO': 23,
#  'Blondie (Band)': 23,
#  'Burzum (Band)': 23,
#  'Celtic Thunder (Band)': 23,
#  'Duran Duran (Music Videos)': 23,
#  'Evanescence (Band)': 23,
#  'GWSN (Band)': 23,
#  'IN2IT (Band)': 23,
#  'jtL (Band)': 23,
#  'Lee Hi (Musician)': 23,
#  'Love Shot - EXO (Music Video)': 23,
#  'Madtown (Band)': 23,
#  'Pitbull (Musician)': 23,
#  'The Rasmus': 23,
#  'Rihanna (Musician)': 23,
#  'Tonight Alive': 23,
#  'VANIRU (Band)': 23,
#  'VoicePlay (Band)': 23,
#  'Aerosmith (Band)': 22,
#  'AJR (Band)': 22,
#  'BlackACE (China Band)': 22,
#  'Blossoms (Band)': 22,
#  'BNM BOYS (Band)': 22,
#  'coldrain (Japan Band)': 22,
#  'COMMUNICATIONS - GHOST | GHOST and Pals (Songs)': 22,
#  'Hey Monday': 22,
#  'Jimi Hendrix Experience': 22,
#  'The Lonely Island (Band)': 22,
#  'M.I.B (Band)': 22,
#  'Midnight Memories - One Direction (Music Video)': 22,
#  'Miley Cyrus (Musician)': 22,
#  'Nine Lives (Band)': 22,
#  'Omega X (Band)': 22,
#  'Rainz (Korea Band)': 22,
#  'TRCNG (Band)': 22,
#  '少年之名 | We Are Young (TV 2020)': 22,
#  '#2Маши | #2Mashi (Band)': 21,
#  'Ashley Dzerigian (Musician)': 21,
#  'Beautiful Liar - VIXX LR (Music Video)': 21,
#  'Blood On The Dance Floor': 21,
#  'Cocoa Otoko': 21,
#  'Girugamesh (Band)': 21,
#  'Hot Chelle Rae': 21,
#  'Killerpilze': 21,
#  'Mad T Party Band': 21,
#  'Pierrot (Band)': 21,
#  'Pulp (Band)': 21,
#  'The Runaways (Band)': 21,
#  'Sixx:A.M.': 21,
#  'SONAMOO (Band)': 21,
#  'Temple of the Dog (Band)': 21,
#  'Ундервуд | Undervud (Band)': 21,
#  'vistlip': 21,
#  'The White Stripes': 21,
#  'Ailee (Musician)': 20,
#  'Amanda Palmer (Musician)': 20,
#  'Audioslave (Band)': 20,
#  'BDC | Boys Da Capo (Band)': 20,
#  'Drake (Musician) RPF': 20,
#  'Fewjar (Band)': 20,
#  'HALO (Korea Band)': 20,
#  'In Real Life (Band)': 20,
#  'Inspiral Carpets (Band)': 20,
#  "Kansai Johnny's Jr.": 20,
#  'Merry (Band)': 20,
#  'The Moffatts': 20,
#  'Neru家 | Neruke (Musician)': 20,
#  'OWV (Japan Band)': 20,
#  'Simon Dominic (Musician)': 20,
#  'The Yardbirds (Band)': 20,
#  '2AM (Band)': 19,
#  'Adam Young (Musician) RPF': 19,
#  'Austin & Ally RPF': 19,
#  'Charlie Puth (Musician)': 19,
#  'Cignature (Band)': 19,
#  'CKY (Band)': 19,
#  'Fighter - Monsta X (Music Video)': 19,
#  'Ghost9 (Korea Band)': 19,
#  'Hello Venus': 19,
#  'Hey Violet (Band)': 19,
#  'Japan (Band)': 19,
#  'Jedward': 19,
#  'MIC男团 | M.I.C. (Band)': 19,
#  'Parties are For Losers - Ferry (Songs)': 19,
#  'Pendulum/Knife Party': 19,
#  'PRETTYMUCH (Band)': 19,
#  'Priest (Sweden Band)': 19,
#  'Rob Zombie (Musician)': 19,
#  'Rocket Punch (Band)': 19,
#  'Sinplus (Band)': 19,
#  'Skyhill (Band)': 19,
#  'BIGSTAR (Band)': 18,
#  'Bruno Mars (Musician)': 18,
#  'Bushido (Musician) RPF': 18,
#  'Chipspeech': 18,
#  'Crown The Empire': 18,
#  'A Day to Remember (Band)': 18,
#  'Edguy (Band)': 18,
#  'ELRIS (Band)': 18,
#  'Elvis Presley (Musician)': 18,
#  'Fantastics from Exile Tribe (Band)': 18,
#  'Jeffree Star (Musician)': 18,
#  'Katy Perry (Musician)': 18,
#  'Marshmello (Musician) RPF': 18,
#  'Макс Барских | Max Barsky (Musician)': 18,
#  'MONTERO (Call Me By Your Name) - Lil Nas X (Music Video)': 18,
#  'Night Changes - One Direction (Music Video)': 18,
#  'Papa Roach': 18,
#  'Project Vela (Band)': 18,
#  'Слава КПСС | Slava KPSS (Musician)': 18,
#  't.A.T.u. (Band)': 18,
#  'Travis Japan': 18,
#  '羽泉 | Yǔ Quán (Band)': 18,
#  'Avril Lavigne (Musician)': 17,
#  'The Beach Boys (Band)': 17,
#  'Beautiful - Monsta X (Music Video)': 17,
#  'The Byrds (Band)': 17,
#  'The Civil Wars (Band)': 17,
#  'DPR LIVE (Musician)': 17,
#  'Feel Special - TWICE (Music Video)': 17,
#  'Frosty the Snowman - All Media Types': 17,
#  'Iggy Pop (Musician)': 17,
#  'JILUKA (Band)': 17,
#  'Jon Bellion (Musician)': 17,
#  'Juice Juice (Band)': 17,
#  'Justice (Band)': 17,
#  'KINGDOM (Korea Band)': 17,
#  'Legion of the Black - Black Veil Brides (Music Video)': 17,
#  'lovelytheband (Band)': 17,
#  'なにわ男子 | Naniwa Danshi (Band)': 17,
#  'Only The Young (Band)': 17,
#  'Planet Booty (Band)': 17,
#  'Rick Astley (Musician)': 17,
#  'S/mileage | ANGERME (Band)': 17,
#  'Santa Cruz (Band)': 17,
#  'Snoop Dogg (Musician)': 17,
#  'Stage Fright (2014)': 17,
#  'To Kill A King (Band)': 17,
#  '超时空 回 - 威神V | Turn Back Time - WayV (Music Video)': 17,
#  'Your Favorite Martian': 17,
#  'B.O.Y (Korea Band)': 16,
#  'Cassidy Haley (Musician)': 16,
#  '天上智喜 The Grace | CSJH The Grace': 16,
#  'Dae Guk Nam Ah | The Boss': 16,
#  'Danny Elfman (Musician)': 16,
#  'Eric Clapton (Musician)': 16,
#  'IM (Band)': 16,
#  'Insane Clown Posse': 16,
#  '木马 | Muma (Band)': 16,
#  'Nik Kershaw (Musician)': 16,
#  '天空少年 | S.K.Y (Band)': 16,
#  'SM the Ballad': 16,
#  'Sweet California (Band)': 16,
#  'Tori Amos (Musician)': 16,
#  'WALK THE MOON (Band)': 16,
#  'Xdinary Heroes (Band)': 16,
#  '69 Eyes': 15,
#  'The Amazing Devil (Band)': 15,
#  'Area 11': 15,
#  'Ashlee Simpson (Musician)': 15,
#  'B.I.Shadow': 15,
#  'Chase Me - Dreamcatcher (Music Video)': 15,
#  'Cherry Bullet (Band)': 15,
#  'Children of Bodom': 15,
#  'Dead Kennedys': 15,
#  'Dirty Computer - Janelle Monáe (Music Video)': 15,
#  'Gamma Ray (Band)': 15,
#  'George Michael (Musician)': 15,
#  '红花会 | Hóng Huā Huì (Band)': 15,
#  'Hunter Hayes (Musician)': 15,
#  'Joan Jett and the Blackhearts': 15,
#  'Lamb of God (Band)': 15,
#  'Last Friday Night - Katy Perry (Music Video)': 15,
#  'Leslie Cheung (Musician)': 15,
#  'Lil Peep (Musician) RPF': 15,
#  'MEGAMASSO (Band)': 15,
#  'MORRIGAN (Japan Band)': 15,
#  'Nega (Band)': 15,
#  'The Pretty Reckless': 15,
#  'Professional Griefers - Deadmau5 ft. Gerard Way (Music Video)': 15,
#  'Shine Forever - Monsta X (Music Video)': 15,
#  'SWMRS (Band)': 15,
#  'Teenage Love Triangle Series - Taylor Swift (Song Cycle)': 15,
#  'Tự Tâm Series - Nguyễn Trần Trung Quân (Music Videos)': 15,
#  '9GOATS BLACK OUT': 14,
#  'The ArchAndroid - Janelle Monáe': 14,
#  'Attack Attack! (Band)': 14,
#  'The Damned (Band)': 14,
#  'Darkthrone (Band)': 14,
#  'Deep Purple (Band)': 14,
#  'Dirty Pretty Things (Band)': 14,
#  'Dream Street (Band)': 14,
#  '逃跑计划 | Escape Plan (Band)': 14,
#  'Fantastic Baby - BIGBANG (Music Video)': 14,
#  'Helloween (Band)': 14,
#  'In This Moment (Band)': 14,
#  'Kesha (Musician)': 14,
#  'Lorde (Musician)': 14,
#  'ミカグラ学園組曲 | Mikagura School Suite - All Media Types': 14,
#  '미래소년 | MIRAE (Band)': 14,
#  '摩登兄弟 | Modern Brothers (Band)': 14,
#  'Nam Yoondo | Eric Nam (Musician)': 14,
#  'Negative (Band)': 14,
#  'New Hope Club (Band)': 14,
#  'Odd Future': 14,
#  'Straylight Run': 14,
#  'Target (Korea Band)': 14,
#  'Telephone - Lady Gaga ft Beyoncé (Music Video)': 14,
#  'Tempo - EXO (Music Video)': 14,
#  'That Poppy (Musician) RPF': 14,
#  'Tool (Band)': 14,
#  'Trans-Siberian Orchestra': 14,
#  'Van Halen': 14,
#  'Whisper - VIXX LR (Music Video)': 14,
#  '백퍼센트 | 100 Percent (Band)': 13,
#  'Alamat (Band)': 13,
#  'Behemoth (Band)': 13,
#  'Beyond (Band)': 13,
#  'Boys generally Asian | BgA': 13,
#  'BREAKERZ': 13,
#  'Bright Eyes (Band)': 13,
#  'Deftones (Band)': 13,
#  'Diplo (Musician)': 13,
#  'Kuroyume': 13,
#  'Laboum (Band)': 13,
#  '凛 -the end of corruption world- | Lin -the End of Corruption World-': 13,
#  'MAX (Musician)': 13,
#  'Moran (Band)': 13,
#  'Mother Love Bone': 13,
#  'NKOTBSB Tour': 13,
#  'NYC (Band)': 13,
#  'Over9000 (Band)': 13,
#  'ペンタゴン | Pentagon (Japan Band)': 13,
#  'Sam Smith (Musician)': 13,
#  'Testament (Band)': 13,
#  'Vidoll': 13,
#  'Wednesday 13 (Band)': 13,
#  'Ya-ya-yah (Band)': 13,
#  '+44 (Band)': 12,
#  'Antic Cafe (Band)': 12,
#  'Beastie Boys (Band)': 12,
#  'Bebe Rexha (Musician)': 12,
#  'Blixa Bargeld (Musician)': 12,
#  'Blue Oyster Cult': 12,
#  'BVNDIT (Band)': 12,
#  'Carach Angren (Band)': 12,
#  'Cinderella (Band)': 12,
#  'Confident - Demi Lovato (Music Video)': 12,
#  '데자부 | Deja Vu - Dreamcatcher (Music Video)': 12,
#  'Dr. Dre (Musician)': 12,
#  'Emerson Lake & Palmer (Band)': 12,
#  'Epica (Band)': 12,
#  'The Fox - Ylvis (Music Video)': 12,
#  'Foxboro Hot Tubs (Band)': 12,
#  'GLAY (Band)': 12,
#  'GOOD DAY (Korea Band)': 12,
#  'Grimes (Musician) RPF': 12,
#  'Hot Milk (Band)': 12,
#  'The Kills': 12,
#  'The Longshot (Band)': 12,
#  'Lovex (Band)': 12,
#  'Mumford & Sons (Band)': 12,
#  'Ozzy Osbourne (Musician)': 12,
#  'Perfume (Band)': 12,
#  'Prince (Musician) RPF': 12,
#  'Slayer (Band)': 12,
#  'The Stooges (Band)': 12,
#  'Sugizo (Musician)': 12,
#  'T.M.Revolution': 12,
#  'TRAX (Korea Band)': 12,
#  'Wallows (Band)': 12,
#  'Weird Al Yankovic (Musician)': 12,
#  'Wham! (Band)': 12,
#  'You Belong With Me - University of Rochester Yellowjackets (Music Video)': 12,
#  'Austin Mahone (Musician)': 11,
#  'Badflower (Band)': 11,
#  'Blank Space - Taylor Swift (Music Video)': 11,
#  'Brian London (Musician)': 11,
#  'Christina Aguilera (Musician)': 11,
#  'Dayshell (Band)': 11,
#  'Desolation Row - My Chemical Romance (Music Video)': 11,
#  '脏手指 | Dirty Fingers (Band)': 11,
#  'Fedez (Musician) RPF': 11,
#  'GLAM (band)': 11,
#  'Halestorm': 11,
#  'Heart Attack - LOONA (Music Video)': 11,
#  'Hizaki Grace Project': 11,
#  'IZ (Band)': 11,
#  'Johnny Cash (Musician)': 11,
#  'Journey (Band)': 11,
#  'JXR (Korea Band)': 11,
#  'Kay Kay and His Weathered Underground (Band)': 11,
#  'こぶしファクトリー | Kobushi Factory': 11,
#  'Mangled - Nathan Sharp (Music Video)': 11,
#  'Metis Gretel': 11,
#  'Michelle Branch (Musician)': 11,
#  ...}

# %%
pd.DataFrame(fandoms_sorted.items(), columns=['Band', 'FanfictionCount']).to_csv('ao3_band_fic_count.csv',sep=';', index = False)

# %% [markdown]
# # TOP 10 UPDATE

# %%
fandoms_sorted = pd.read_csv('ao3_band_fic_count.csv', sep=';')
fandoms_sorted.drop(index=6).reset_index(drop=True).to_csv('ao3_band_fic_count_update.csv',sep=';', index = False)

# %%
top10 = pd.read_csv('ao3_band_fic_count_update.csv', sep=';')
top10
# Out:
#                          Band  FanfictionCount
# 0  방탄소년단 | Bangtan Boys | BTS           169884
# 1        One Direction (Band)            61598
# 2                  NCT (Band)            51666
# 3                  EXO (Band)            44190
# 4            SEVENTEEN (Band)            27594
# 5           Stray Kids (Band)            26409
# 6         My Chemical Romance            17376
# 7                        GOT7            14328
# 8             Monsta X (Band)            11556
# 9                ATEEZ (Band)            11083

# %% [markdown]
# # POBIERANIE DANYCH

# %%
# multi: (po 'id')
# 'categories', 'characters', 'fandoms', 'relationships', 'tags', 'warnings', 'authors', 'series'

# single:
# 'id', 'date_updated', 'bookmarks', 'nchapters', 'complete', 'comments', 'hits', 'kudos', 'language', 'rating', 'status', 'summary', 'title', 'words'

# %%
bts = top10.iloc[0, 0]

# %%
bands = top10.iloc[1:, 0]

# %%
for num, band in enumerate(bands):
    print(num+1, band)
# Out:
# 1 One Direction (Band)
# 2 NCT (Band)
# 3 EXO (Band)
# 4 SEVENTEEN (Band)
# 5 Stray Kids (Band)
# 6 My Chemical Romance
# 7 GOT7
# 8 Monsta X (Band)
# 9 ATEEZ (Band)

# %%
bts
# Out:
# '방탄소년단 | Bangtan Boys | BTS'

# %%
def get_page_data(search):

    data_single = pd.DataFrame(columns=['id', 'date_updated', 'bookmarks', 'nchapters', 'complete', 'comments', 'hits', 'kudos', 'language', 'rating', 'status', 'summary', 'title', 'words'])
    data_multi = pd.DataFrame(columns=['id', 'meta_name', 'meta_val'])
    meta_multi = ['categories', 'characters', 'fandoms', 'relationships', 'tags', 'warnings', 'authors', 'series']
    meta_single = ['id', 'date_updated', 'bookmarks', 'nchapters', 'complete', 'comments', 'hits', 'kudos', 'language', 'rating', 'status', 'summary', 'title', 'words']

    for result in search.results:
        meta_dict = {}
        for meta in meta_single:
            try:
                meta_dict[meta] = result.metadata[meta]
            except Exception:
                meta_dict[meta] = 0
        data_single = data_single.append(meta_dict, ignore_index=True)

        for meta in meta_multi:
            meta_dict = {}
            for value in result.metadata[meta]:
                meta_dict['id'] = result.metadata['id']
                meta_dict['meta_name'] = meta
                meta_dict['meta_val'] = value
                data_multi = data_multi.append(meta_dict, ignore_index=True)
    return data_single, data_multi

# %%
# with open('pass.txt', 'r') as file:
#     password = file.read()

# %%
# sess = AO3.Session("Spama", password)
sess = AO3.GuestSession()

# %%
search = AO3.Search(fandoms=bts, any_field='sort:>updated', revised_at='>2020-01-01', session=sess)
search.update()
print(search.total_results)
print(search.pages)
# Out:
# 79673
# 3984

# %%
data_single = pd.DataFrame(columns=['id', 'date_updated', 'bookmarks', 'nchapters', 'complete', 'comments', 'hits', 'kudos', 'language', 'rating', 'status', 'summary', 'title', 'words'])
data_multi = pd.DataFrame(columns=['id', 'meta_name', 'meta_val'])
data_single.to_csv('ao3_band_fic_metadata_part2.csv', sep=';', index = False, mode='a')
data_multi.to_csv('ao3_band_tag_metadata_part2.csv', sep=';', index = False, mode='a')

for i in trange(1, search.pages+1):
    search.page = i
    wait_time = 0
    while True:
        try:
            search.update()
            sys.stdout.write('\r                                                           ')
            break
        except Exception:
            wait_time+=15
            sys.stdout.write(f'\r Waiting for page {i}... {wait_time}s                     ')
            time.sleep(15)
    page_single, page_multi = get_page_data(search)
    page_single.to_csv('ao3_band_fic_metadata_part2.csv', sep=';', index = False, mode='a', header=False)
    page_multi.to_csv('ao3_band_tag_metadata_part2.csv', sep=';', index = False, mode='a', header=False)
#     data_single = data_single.append(page_single, ignore_index=True)
#     data_multi = data_multi.append(page_multi, ignore_index=True)
# Out:
#   0%|          | 0/3984 [00:00<?, ?it/s]

# %%
data_single = pd.DataFrame(columns=['id', 'date_updated', 'bookmarks', 'nchapters', 'complete', 'comments', 'hits', 'kudos', 'language', 'rating', 'status', 'summary', 'title', 'words'])
data_multi = pd.DataFrame(columns=['id', 'meta_name', 'meta_val'])
data_single.to_csv('ao3_band_fic_metadata_part3.csv', sep=';', index = False, mode='a')
data_multi.to_csv('ao3_band_tag_metadata_part3.csv', sep=';', index = False, mode='a')

for j, band in enumerate(bands):
    search = AO3.Search(fandoms=band, any_field='sort:>updated', session=sess)
    search.update()
    band_number = j+1
    print(f'{band_number}/9: {band}')
    
    for i in trange(1, search.pages+1):
        search.page = i
        wait_time = 0
        while True:
            try:
                search.update()
                sys.stdout.write('\r                                                           ')
                break
            except Exception:
                wait_time+=15
                sys.stdout.write(f'\r Waiting for page {i}... {wait_time}s                     ')
                time.sleep(15)
        page_single, page_multi = get_page_data(search)
        page_single.to_csv('ao3_band_fic_metadata_part3.csv', sep=';', index = False, mode='a', header=False)
        page_multi.to_csv('ao3_band_tag_metadata_part3.csv', sep=';', index = False, mode='a', header=False)
# Out:
# 1/9: One Direction (Band)
#   0%|          | 0/3072 [00:00<?, ?it/s]
#                                                            2/9: NCT (Band)
#   0%|          | 0/2581 [00:00<?, ?it/s]
#                                                            3/9: EXO (Band)
#   0%|          | 0/2178 [00:00<?, ?it/s]
#                                                            4/9: SEVENTEEN (Band)
#   0%|          | 0/1373 [00:00<?, ?it/s]
#                                                            5/9: Stray Kids (Band)
#   0%|          | 0/1330 [00:00<?, ?it/s]
#                                                            6/9: My Chemical Romance
#   0%|          | 0/868 [00:00<?, ?it/s]
#                                                            7/9: GOT7
#   0%|          | 0/712 [00:00<?, ?it/s]
#                                                            8/9: Monsta X (Band)
#   0%|          | 0/578 [00:00<?, ?it/s]
#                                                            9/9: ATEEZ (Band)
#   0%|          | 0/557 [00:00<?, ?it/s]

# %%
# data_single.to_csv('ao3_band_fic_metadata_part1.csv', sep=';', index = False)
# data_multi.to_csv('ao3_band_tag_metadata_part1.csv', sep=';', index = False)

# %% [markdown]
# # CLEANING

# %%
fic1 = pd.read_csv('ao3_band_fic_metadata_part1.csv', sep=';')
tag1 = pd.read_csv('ao3_band_tag_metadata_part1.csv', sep=';')
fic2 = pd.read_csv('ao3_band_fic_metadata_part2.csv', sep=';')
tag2 = pd.read_csv('ao3_band_tag_metadata_part2.csv', sep=';')
fic3 = pd.read_csv('ao3_band_fic_metadata_part3.csv', sep=';')
tag3 = pd.read_csv('ao3_band_tag_metadata_part3.csv', sep=';')

# %%
fic1 = fic1.append(fic2, ignore_index=True)
fic1 = fic1.append(fic3, ignore_index=True)
tag1 = tag1.append(tag2, ignore_index=True)
tag1 = tag1.append(tag3, ignore_index=True)

# %%
fic1 = fic1.sort_values(by='date_updated', ascending=True)

# %%
fic1 = fic1.drop_duplicates(subset=['id'], keep='last', ignore_index=True)

# %%
tag1 = tag1.drop_duplicates(ignore_index=True)

# %%
fic = fic1
tag = tag1

# %%
fic = fic.replace(to_replace='\n', value='', regex=True)
fic = fic.replace(to_replace='\\', value='', regex=True)
fic = fic.replace(to_replace=';', value=':', regex=True)
fic = fic.replace(to_replace='"', value='\'', regex=True)
tag = tag.replace(to_replace='\n', value='', regex=True)
tag = tag.replace(to_replace='\\', value='', regex=True)
tag = tag.replace(to_replace=';', value=':', regex=True)
tag = tag.replace(to_replace='"', value='\'', regex=True)

# %%
fic = fic.fillna('N//A')

# %%
fic[fic['title'].str.contains("N//A")]
# Out:
#               id         date_updated  bookmarks  nchapters  complete  \
# 213339  20218804  2019-08-12 00:00:00          3          1      True
# 409889  33760678  2021-11-14 00:00:00         11          5     False
#
#         comments  hits  kudos language    rating     status  \
# 213339         5   248     33  English  Explicit  Completed
# 409889        16  3146     77  English    Mature          0
#
#                                                   summary title  words
# 213339  What’s the meaning of life? Is it to exist? Is...  N//A   4637
# 409889  If you have a title idea for this please hit m...  N//A  13325

# %% [markdown]
# # Unifikacja fandomów

# %%
# 

fandom_string = ['bts', 'one direction', 'nct', 'exo', 'stray kids', 'seventeen', 'got7', 'ateez', 'my chemical romance', 'monsta x', '1d', '1 d', 'one d', 'mcr']
fandom_new = ["BTS", "One Direction", "NCT 127", "EXO", "Stray Kids", "SEVENTEEN", "GOT7", "ATEEZ", "My Chemical Romance", "Monsta X", 'One Direction', 'One Direction', 'One Direction', 'My Chemical Romance']

# %%
for i in tqdm(range(len(fandom_new))):
    tag.loc[(tag['meta_name']=='fandoms') & (tag['meta_val'].str.contains(fandom_string[i], na=False, case=False)), 'meta_val'] = fandom_new[i]
# Out:
#   0%|          | 0/14 [00:00<?, ?it/s]

# %%
tag.loc[tag['meta_name']=='fandoms']
# Out:
#                id meta_name            meta_val
# 11       21850933   fandoms                 BTS
# 12       21850933   fandoms  Shadowhunters (TV)
# 54       32131123   fandoms                 BTS
# 66        1588073   fandoms                 BTS
# 71         916078   fandoms                 BTS
# ...           ...       ...                 ...
# 8866826  35996851   fandoms               ATEEZ
# 8866846  35962633   fandoms               ATEEZ
# 8866872  35987128   fandoms               ATEEZ
# 8866890  35988667   fandoms               ATEEZ
# 8866908  35986399   fandoms               ATEEZ
#
# [512874 rows x 3 columns]

# %% [markdown]
# # Zapis

# %%
tag.to_csv('ao3_band_tag_metadata_clean.csv', sep=';', index = False)
fic.to_csv('ao3_band_fic_metadata_clean.csv', sep=';', index = False, quoting=csv.QUOTE_NONNUMERIC)
